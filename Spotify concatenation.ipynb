# %% [markdown]
# # Spotify Playlists concatenation

# %%
import numpy as np
import pandas as pd

# %%
file1=pd.read_csv("Data/hot100_Spanish_songs.csv")
file2=pd.read_csv("Data/hot1000_greatest_song.csv")
file3=pd.read_csv("Data/hiphop.csv")
file4=pd.read_csv("Data/10000songs.csv")
file5=pd.read_csv("Data/biggest_playlist.csv")
file6=pd.read_csv("Data/Spanish_songs.csv")
file7=pd.read_csv("Data/Clasic_music.csv")
file8=pd.read_csv("Data/k-pop.csv")

# %%
df=pd.concat([file1,file2,file3,file4,file5,file6,file7,file8],axis=0).reset_index(drop=True)

# %%
df
# Out:
#                                     songs         artists  \
# 0                                   Pepas         Farruko
# 1                                   Volví        Aventura
# 2                                Yonaguni       Bad Bunny
# 3                               Invisible           Andra
# 4                              Todo De Ti  Rauw Alejandro
# ...                                   ...             ...
# 13586           Outro: Circle Room Cypher             BTS
# 13587                       No More Dream             BTS
# 13588                              Butter             BTS
# 13589  Butter (feat. Megan Thee Stallion)             BTS
# 13590                         My Universe        Coldplay
#
#                                         uri  danceability  energy  key  \
# 0      spotify:track:5fwSHlTEWpluwOM0Sxnh5k         0.762   0.766    7
# 1      spotify:track:5fwSHlTEWpluwOM0Sxnh5k         0.762   0.766    7
# 2      spotify:track:5fwSHlTEWpluwOM0Sxnh5k         0.762   0.766    7
# 3      spotify:track:5fwSHlTEWpluwOM0Sxnh5k         0.762   0.766    7
# 4      spotify:track:5fwSHlTEWpluwOM0Sxnh5k         0.762   0.766    7
# ...                                     ...           ...     ...  ...
# 13586  spotify:track:5BzfRtVjyC4wbISHdbCvWL         0.588   0.568    4
# 13587  spotify:track:5BzfRtVjyC4wbISHdbCvWL         0.588   0.568    4
# 13588  spotify:track:5BzfRtVjyC4wbISHdbCvWL         0.588   0.568    4
# 13589  spotify:track:5BzfRtVjyC4wbISHdbCvWL         0.588   0.568    4
# 13590  spotify:track:5BzfRtVjyC4wbISHdbCvWL         0.588   0.568    4
#
#        loudness  mode  speechiness  acousticness  ...  liveness  valence  \
# 0        -3.955     1       0.0343       0.00776  ...     0.128    0.442
# 1        -3.955     1       0.0343       0.00776  ...     0.128    0.442
# 2        -3.955     1       0.0343       0.00776  ...     0.128    0.442
# 3        -3.955     1       0.0343       0.00776  ...     0.128    0.442
# 4        -3.955     1       0.0343       0.00776  ...     0.128    0.442
# ...         ...   ...          ...           ...  ...       ...      ...
# 13586    -2.787     1       0.0271       0.22500  ...     0.138    0.393
# 13587    -2.787     1       0.0271       0.22500  ...     0.138    0.393
# 13588    -2.787     1       0.0271       0.22500  ...     0.138    0.393
# 13589    -2.787     1       0.0271       0.22500  ...     0.138    0.393
# 13590    -2.787     1       0.0271       0.22500  ...     0.138    0.393
#
#          tempo            type                      id  \
# 0      130.001  audio_features  5fwSHlTEWpluwOM0Sxnh5k
# 1      130.001  audio_features  5fwSHlTEWpluwOM0Sxnh5k
# 2      130.001  audio_features  5fwSHlTEWpluwOM0Sxnh5k
# 3      130.001  audio_features  5fwSHlTEWpluwOM0Sxnh5k
# 4      130.001  audio_features  5fwSHlTEWpluwOM0Sxnh5k
# ...        ...             ...                     ...
# 13586   94.830  audio_features  5BzfRtVjyC4wbISHdbCvWL
# 13587   94.830  audio_features  5BzfRtVjyC4wbISHdbCvWL
# 13588   94.830  audio_features  5BzfRtVjyC4wbISHdbCvWL
# 13589   94.830  audio_features  5BzfRtVjyC4wbISHdbCvWL
# 13590   94.830  audio_features  5BzfRtVjyC4wbISHdbCvWL
#
#                                       uri.1  \
# 0      spotify:track:5fwSHlTEWpluwOM0Sxnh5k
# 1      spotify:track:5fwSHlTEWpluwOM0Sxnh5k
# 2      spotify:track:5fwSHlTEWpluwOM0Sxnh5k
# 3      spotify:track:5fwSHlTEWpluwOM0Sxnh5k
# 4      spotify:track:5fwSHlTEWpluwOM0Sxnh5k
# ...                                     ...
# 13586  spotify:track:5BzfRtVjyC4wbISHdbCvWL
# 13587  spotify:track:5BzfRtVjyC4wbISHdbCvWL
# 13588  spotify:track:5BzfRtVjyC4wbISHdbCvWL
# 13589  spotify:track:5BzfRtVjyC4wbISHdbCvWL
# 13590  spotify:track:5BzfRtVjyC4wbISHdbCvWL
#
#                                               track_href  \
# 0      https://api.spotify.com/v1/tracks/5fwSHlTEWplu...
# 1      https://api.spotify.com/v1/tracks/5fwSHlTEWplu...
# 2      https://api.spotify.com/v1/tracks/5fwSHlTEWplu...
# 3      https://api.spotify.com/v1/tracks/5fwSHlTEWplu...
# 4      https://api.spotify.com/v1/tracks/5fwSHlTEWplu...
# ...                                                  ...
# 13586  https://api.spotify.com/v1/tracks/5BzfRtVjyC4w...
# 13587  https://api.spotify.com/v1/tracks/5BzfRtVjyC4w...
# 13588  https://api.spotify.com/v1/tracks/5BzfRtVjyC4w...
# 13589  https://api.spotify.com/v1/tracks/5BzfRtVjyC4w...
# 13590  https://api.spotify.com/v1/tracks/5BzfRtVjyC4w...
#
#                                             analysis_url duration_ms  \
# 0      https://api.spotify.com/v1/audio-analysis/5fwS...      287120
# 1      https://api.spotify.com/v1/audio-analysis/5fwS...      287120
# 2      https://api.spotify.com/v1/audio-analysis/5fwS...      287120
# 3      https://api.spotify.com/v1/audio-analysis/5fwS...      287120
# 4      https://api.spotify.com/v1/audio-analysis/5fwS...      287120
# ...                                                  ...         ...
# 13586  https://api.spotify.com/v1/audio-analysis/5Bzf...      209987
# 13587  https://api.spotify.com/v1/audio-analysis/5Bzf...      209987
# 13588  https://api.spotify.com/v1/audio-analysis/5Bzf...      209987
# 13589  https://api.spotify.com/v1/audio-analysis/5Bzf...      209987
# 13590  https://api.spotify.com/v1/audio-analysis/5Bzf...      209987
#
#        time_signature
# 0                   4
# 1                   4
# 2                   4
# 3                   4
# 4                   4
# ...               ...
# 13586               4
# 13587               4
# 13588               4
# 13589               4
# 13590               4
#
# [13591 rows x 21 columns]

# %%
def clean_data(df):
    
    df=df.dropna()
    df=df.drop_duplicates(inplace=True)
    
    return df

# %%
df
# Out:
#                                     songs         artists  \
# 0                                   Pepas         Farruko
# 1                                   Volví        Aventura
# 2                                Yonaguni       Bad Bunny
# 3                               Invisible           Andra
# 4                              Todo De Ti  Rauw Alejandro
# ...                                   ...             ...
# 13586           Outro: Circle Room Cypher             BTS
# 13587                       No More Dream             BTS
# 13588                              Butter             BTS
# 13589  Butter (feat. Megan Thee Stallion)             BTS
# 13590                         My Universe        Coldplay
#
#                                         uri  danceability  energy  key  \
# 0      spotify:track:5fwSHlTEWpluwOM0Sxnh5k         0.762   0.766    7
# 1      spotify:track:5fwSHlTEWpluwOM0Sxnh5k         0.762   0.766    7
# 2      spotify:track:5fwSHlTEWpluwOM0Sxnh5k         0.762   0.766    7
# 3      spotify:track:5fwSHlTEWpluwOM0Sxnh5k         0.762   0.766    7
# 4      spotify:track:5fwSHlTEWpluwOM0Sxnh5k         0.762   0.766    7
# ...                                     ...           ...     ...  ...
# 13586  spotify:track:5BzfRtVjyC4wbISHdbCvWL         0.588   0.568    4
# 13587  spotify:track:5BzfRtVjyC4wbISHdbCvWL         0.588   0.568    4
# 13588  spotify:track:5BzfRtVjyC4wbISHdbCvWL         0.588   0.568    4
# 13589  spotify:track:5BzfRtVjyC4wbISHdbCvWL         0.588   0.568    4
# 13590  spotify:track:5BzfRtVjyC4wbISHdbCvWL         0.588   0.568    4
#
#        loudness  mode  speechiness  acousticness  ...  liveness  valence  \
# 0        -3.955     1       0.0343       0.00776  ...     0.128    0.442
# 1        -3.955     1       0.0343       0.00776  ...     0.128    0.442
# 2        -3.955     1       0.0343       0.00776  ...     0.128    0.442
# 3        -3.955     1       0.0343       0.00776  ...     0.128    0.442
# 4        -3.955     1       0.0343       0.00776  ...     0.128    0.442
# ...         ...   ...          ...           ...  ...       ...      ...
# 13586    -2.787     1       0.0271       0.22500  ...     0.138    0.393
# 13587    -2.787     1       0.0271       0.22500  ...     0.138    0.393
# 13588    -2.787     1       0.0271       0.22500  ...     0.138    0.393
# 13589    -2.787     1       0.0271       0.22500  ...     0.138    0.393
# 13590    -2.787     1       0.0271       0.22500  ...     0.138    0.393
#
#          tempo            type                      id  \
# 0      130.001  audio_features  5fwSHlTEWpluwOM0Sxnh5k
# 1      130.001  audio_features  5fwSHlTEWpluwOM0Sxnh5k
# 2      130.001  audio_features  5fwSHlTEWpluwOM0Sxnh5k
# 3      130.001  audio_features  5fwSHlTEWpluwOM0Sxnh5k
# 4      130.001  audio_features  5fwSHlTEWpluwOM0Sxnh5k
# ...        ...             ...                     ...
# 13586   94.830  audio_features  5BzfRtVjyC4wbISHdbCvWL
# 13587   94.830  audio_features  5BzfRtVjyC4wbISHdbCvWL
# 13588   94.830  audio_features  5BzfRtVjyC4wbISHdbCvWL
# 13589   94.830  audio_features  5BzfRtVjyC4wbISHdbCvWL
# 13590   94.830  audio_features  5BzfRtVjyC4wbISHdbCvWL
#
#                                       uri.1  \
# 0      spotify:track:5fwSHlTEWpluwOM0Sxnh5k
# 1      spotify:track:5fwSHlTEWpluwOM0Sxnh5k
# 2      spotify:track:5fwSHlTEWpluwOM0Sxnh5k
# 3      spotify:track:5fwSHlTEWpluwOM0Sxnh5k
# 4      spotify:track:5fwSHlTEWpluwOM0Sxnh5k
# ...                                     ...
# 13586  spotify:track:5BzfRtVjyC4wbISHdbCvWL
# 13587  spotify:track:5BzfRtVjyC4wbISHdbCvWL
# 13588  spotify:track:5BzfRtVjyC4wbISHdbCvWL
# 13589  spotify:track:5BzfRtVjyC4wbISHdbCvWL
# 13590  spotify:track:5BzfRtVjyC4wbISHdbCvWL
#
#                                               track_href  \
# 0      https://api.spotify.com/v1/tracks/5fwSHlTEWplu...
# 1      https://api.spotify.com/v1/tracks/5fwSHlTEWplu...
# 2      https://api.spotify.com/v1/tracks/5fwSHlTEWplu...
# 3      https://api.spotify.com/v1/tracks/5fwSHlTEWplu...
# 4      https://api.spotify.com/v1/tracks/5fwSHlTEWplu...
# ...                                                  ...
# 13586  https://api.spotify.com/v1/tracks/5BzfRtVjyC4w...
# 13587  https://api.spotify.com/v1/tracks/5BzfRtVjyC4w...
# 13588  https://api.spotify.com/v1/tracks/5BzfRtVjyC4w...
# 13589  https://api.spotify.com/v1/tracks/5BzfRtVjyC4w...
# 13590  https://api.spotify.com/v1/tracks/5BzfRtVjyC4w...
#
#                                             analysis_url duration_ms  \
# 0      https://api.spotify.com/v1/audio-analysis/5fwS...      287120
# 1      https://api.spotify.com/v1/audio-analysis/5fwS...      287120
# 2      https://api.spotify.com/v1/audio-analysis/5fwS...      287120
# 3      https://api.spotify.com/v1/audio-analysis/5fwS...      287120
# 4      https://api.spotify.com/v1/audio-analysis/5fwS...      287120
# ...                                                  ...         ...
# 13586  https://api.spotify.com/v1/audio-analysis/5Bzf...      209987
# 13587  https://api.spotify.com/v1/audio-analysis/5Bzf...      209987
# 13588  https://api.spotify.com/v1/audio-analysis/5Bzf...      209987
# 13589  https://api.spotify.com/v1/audio-analysis/5Bzf...      209987
# 13590  https://api.spotify.com/v1/audio-analysis/5Bzf...      209987
#
#        time_signature
# 0                   4
# 1                   4
# 2                   4
# 3                   4
# 4                   4
# ...               ...
# 13586               4
# 13587               4
# 13588               4
# 13589               4
# 13590               4
#
# [13591 rows x 21 columns]
