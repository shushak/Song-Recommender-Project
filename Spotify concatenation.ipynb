# %% [markdown]
# # Spotify Playlists concatenation

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("Data/songs_db.csv")

# %%
#df=pd.concat([file1,file2,file3,file4,file5,file6,file7],axis=0).reset_index(drop=True)

# %%
df
# Out:
#        srno                                songs        artists  \
# 0         0  Bohemian Rhapsody - Remastered 2011          Queen
# 1         1                  Sweet Child O' Mine  Guns N' Roses
# 2         2              Smells Like Teen Spirit        Nirvana
# 3         3            Imagine - Remastered 2010    John Lennon
# 4         4                     You're the Voice   John Farnham
# ...     ...                                  ...            ...
# 12233   665                           Water Baby      Tom Misch
# 12234   666                    You're On My Mind      Tom Misch
# 12235   667                       Cos I Love You      Tom Misch
# 12236   668                    We've Come So Far      Tom Misch
# 12237   669                               Follow      Tom Misch
#
#                                        uris  danceability  energy  key  \
# 0      spotify:track:4u7EnebtmKWzUH433cf5Qv         0.414   0.404    0
# 1      spotify:track:7o2CTH4ctstm8TNelqjb51         0.454   0.910    6
# 2      spotify:track:4CeeEOM32jQcH3eN9Q2dGj         0.502   0.912    1
# 3      spotify:track:7pKfPomDEeI4TPT6EOYjn9         0.547   0.257    0
# 4      spotify:track:5NwkWwfRJaT55hEPtCmJHx         0.369   0.762   10
# ...                                     ...           ...     ...  ...
# 12233  spotify:track:6Pd20wirRDM9k4e69px3dN         0.666   0.537    8
# 12234  spotify:track:0ORL2BIQwHdshE8Zp2En2M         0.785   0.394    4
# 12235  spotify:track:58xN31xmYcfrgA56gAeM3W         0.836   0.678    5
# 12236  spotify:track:46mMjdrfaJicOdrOA7NtBa         0.569   0.409    2
# 12237  spotify:track:2uROM73VxtppgLSE2k27nf         0.785   0.367    4
#
#        loudness  mode  speechiness  ...  liveness  valence    tempo  \
# 0        -9.928     0       0.0499  ...    0.3000   0.2240   71.105
# 1        -7.766     1       0.0448  ...    0.1160   0.6290  125.116
# 2        -4.556     1       0.0564  ...    0.1060   0.7200  116.761
# 3       -12.358     1       0.0252  ...    0.0935   0.1690   75.752
# 4        -8.993     1       0.0464  ...    0.5790   0.6440   84.957
# ...         ...   ...          ...  ...       ...      ...      ...
# 12233   -10.467     1       0.2490  ...    0.0656   0.6530   93.002
# 12234    -8.010     1       0.0392  ...    0.1110   0.1310  100.002
# 12235    -8.206     0       0.0990  ...    0.3690   0.6330  116.020
# 12236   -10.612     1       0.0396  ...    0.0971   0.0948  118.028
# 12237    -8.483     0       0.0363  ...    0.0902   0.4680   90.003
#
#                  type                      id  \
# 0      audio_features  4u7EnebtmKWzUH433cf5Qv
# 1      audio_features  7o2CTH4ctstm8TNelqjb51
# 2      audio_features  4CeeEOM32jQcH3eN9Q2dGj
# 3      audio_features  7pKfPomDEeI4TPT6EOYjn9
# 4      audio_features  5NwkWwfRJaT55hEPtCmJHx
# ...               ...                     ...
# 12233  audio_features  6Pd20wirRDM9k4e69px3dN
# 12234  audio_features  0ORL2BIQwHdshE8Zp2En2M
# 12235  audio_features  58xN31xmYcfrgA56gAeM3W
# 12236  audio_features  46mMjdrfaJicOdrOA7NtBa
# 12237  audio_features  2uROM73VxtppgLSE2k27nf
#
#                                         uri  \
# 0      spotify:track:4u7EnebtmKWzUH433cf5Qv
# 1      spotify:track:7o2CTH4ctstm8TNelqjb51
# 2      spotify:track:4CeeEOM32jQcH3eN9Q2dGj
# 3      spotify:track:7pKfPomDEeI4TPT6EOYjn9
# 4      spotify:track:5NwkWwfRJaT55hEPtCmJHx
# ...                                     ...
# 12233  spotify:track:6Pd20wirRDM9k4e69px3dN
# 12234  spotify:track:0ORL2BIQwHdshE8Zp2En2M
# 12235  spotify:track:58xN31xmYcfrgA56gAeM3W
# 12236  spotify:track:46mMjdrfaJicOdrOA7NtBa
# 12237  spotify:track:2uROM73VxtppgLSE2k27nf
#
#                                               track_href  \
# 0      https://api.spotify.com/v1/tracks/4u7EnebtmKWz...
# 1      https://api.spotify.com/v1/tracks/7o2CTH4ctstm...
# 2      https://api.spotify.com/v1/tracks/4CeeEOM32jQc...
# 3      https://api.spotify.com/v1/tracks/7pKfPomDEeI4...
# 4      https://api.spotify.com/v1/tracks/5NwkWwfRJaT5...
# ...                                                  ...
# 12233  https://api.spotify.com/v1/tracks/6Pd20wirRDM9...
# 12234  https://api.spotify.com/v1/tracks/0ORL2BIQwHds...
# 12235  https://api.spotify.com/v1/tracks/58xN31xmYcfr...
# 12236  https://api.spotify.com/v1/tracks/46mMjdrfaJic...
# 12237  https://api.spotify.com/v1/tracks/2uROM73Vxtpp...
#
#                                             analysis_url duration_ms  \
# 0      https://api.spotify.com/v1/audio-analysis/4u7E...      354320
# 1      https://api.spotify.com/v1/audio-analysis/7o2C...      354520
# 2      https://api.spotify.com/v1/audio-analysis/4Cee...      301920
# 3      https://api.spotify.com/v1/audio-analysis/7pKf...      187867
# 4      https://api.spotify.com/v1/audio-analysis/5Nwk...      302107
# ...                                                  ...         ...
# 12233  https://api.spotify.com/v1/audio-analysis/6Pd2...      271530
# 12234  https://api.spotify.com/v1/audio-analysis/0ORL...      258747
# 12235  https://api.spotify.com/v1/audio-analysis/58xN...      253711
# 12236  https://api.spotify.com/v1/audio-analysis/46mM...      233465
# 12237  https://api.spotify.com/v1/audio-analysis/2uRO...      225341
#
#       time_signature
# 0                  4
# 1                  4
# 2                  4
# 3                  4
# 4                  4
# ...              ...
# 12233              4
# 12234              4
# 12235              4
# 12236              5
# 12237              4
#
# [12238 rows x 22 columns]

# %%
def clean_data(df):
    
    df=df.dropna()
    df=df.drop_duplicates(inplace=True)
    
    return df

# %%
df
# Out:
#        srno                                songs        artists  \
# 0         0  Bohemian Rhapsody - Remastered 2011          Queen
# 1         1                  Sweet Child O' Mine  Guns N' Roses
# 2         2              Smells Like Teen Spirit        Nirvana
# 3         3            Imagine - Remastered 2010    John Lennon
# 4         4                     You're the Voice   John Farnham
# ...     ...                                  ...            ...
# 12233   665                           Water Baby      Tom Misch
# 12234   666                    You're On My Mind      Tom Misch
# 12235   667                       Cos I Love You      Tom Misch
# 12236   668                    We've Come So Far      Tom Misch
# 12237   669                               Follow      Tom Misch
#
#                                        uris  danceability  energy  key  \
# 0      spotify:track:4u7EnebtmKWzUH433cf5Qv         0.414   0.404    0
# 1      spotify:track:7o2CTH4ctstm8TNelqjb51         0.454   0.910    6
# 2      spotify:track:4CeeEOM32jQcH3eN9Q2dGj         0.502   0.912    1
# 3      spotify:track:7pKfPomDEeI4TPT6EOYjn9         0.547   0.257    0
# 4      spotify:track:5NwkWwfRJaT55hEPtCmJHx         0.369   0.762   10
# ...                                     ...           ...     ...  ...
# 12233  spotify:track:6Pd20wirRDM9k4e69px3dN         0.666   0.537    8
# 12234  spotify:track:0ORL2BIQwHdshE8Zp2En2M         0.785   0.394    4
# 12235  spotify:track:58xN31xmYcfrgA56gAeM3W         0.836   0.678    5
# 12236  spotify:track:46mMjdrfaJicOdrOA7NtBa         0.569   0.409    2
# 12237  spotify:track:2uROM73VxtppgLSE2k27nf         0.785   0.367    4
#
#        loudness  mode  speechiness  ...  liveness  valence    tempo  \
# 0        -9.928     0       0.0499  ...    0.3000   0.2240   71.105
# 1        -7.766     1       0.0448  ...    0.1160   0.6290  125.116
# 2        -4.556     1       0.0564  ...    0.1060   0.7200  116.761
# 3       -12.358     1       0.0252  ...    0.0935   0.1690   75.752
# 4        -8.993     1       0.0464  ...    0.5790   0.6440   84.957
# ...         ...   ...          ...  ...       ...      ...      ...
# 12233   -10.467     1       0.2490  ...    0.0656   0.6530   93.002
# 12234    -8.010     1       0.0392  ...    0.1110   0.1310  100.002
# 12235    -8.206     0       0.0990  ...    0.3690   0.6330  116.020
# 12236   -10.612     1       0.0396  ...    0.0971   0.0948  118.028
# 12237    -8.483     0       0.0363  ...    0.0902   0.4680   90.003
#
#                  type                      id  \
# 0      audio_features  4u7EnebtmKWzUH433cf5Qv
# 1      audio_features  7o2CTH4ctstm8TNelqjb51
# 2      audio_features  4CeeEOM32jQcH3eN9Q2dGj
# 3      audio_features  7pKfPomDEeI4TPT6EOYjn9
# 4      audio_features  5NwkWwfRJaT55hEPtCmJHx
# ...               ...                     ...
# 12233  audio_features  6Pd20wirRDM9k4e69px3dN
# 12234  audio_features  0ORL2BIQwHdshE8Zp2En2M
# 12235  audio_features  58xN31xmYcfrgA56gAeM3W
# 12236  audio_features  46mMjdrfaJicOdrOA7NtBa
# 12237  audio_features  2uROM73VxtppgLSE2k27nf
#
#                                         uri  \
# 0      spotify:track:4u7EnebtmKWzUH433cf5Qv
# 1      spotify:track:7o2CTH4ctstm8TNelqjb51
# 2      spotify:track:4CeeEOM32jQcH3eN9Q2dGj
# 3      spotify:track:7pKfPomDEeI4TPT6EOYjn9
# 4      spotify:track:5NwkWwfRJaT55hEPtCmJHx
# ...                                     ...
# 12233  spotify:track:6Pd20wirRDM9k4e69px3dN
# 12234  spotify:track:0ORL2BIQwHdshE8Zp2En2M
# 12235  spotify:track:58xN31xmYcfrgA56gAeM3W
# 12236  spotify:track:46mMjdrfaJicOdrOA7NtBa
# 12237  spotify:track:2uROM73VxtppgLSE2k27nf
#
#                                               track_href  \
# 0      https://api.spotify.com/v1/tracks/4u7EnebtmKWz...
# 1      https://api.spotify.com/v1/tracks/7o2CTH4ctstm...
# 2      https://api.spotify.com/v1/tracks/4CeeEOM32jQc...
# 3      https://api.spotify.com/v1/tracks/7pKfPomDEeI4...
# 4      https://api.spotify.com/v1/tracks/5NwkWwfRJaT5...
# ...                                                  ...
# 12233  https://api.spotify.com/v1/tracks/6Pd20wirRDM9...
# 12234  https://api.spotify.com/v1/tracks/0ORL2BIQwHds...
# 12235  https://api.spotify.com/v1/tracks/58xN31xmYcfr...
# 12236  https://api.spotify.com/v1/tracks/46mMjdrfaJic...
# 12237  https://api.spotify.com/v1/tracks/2uROM73Vxtpp...
#
#                                             analysis_url duration_ms  \
# 0      https://api.spotify.com/v1/audio-analysis/4u7E...      354320
# 1      https://api.spotify.com/v1/audio-analysis/7o2C...      354520
# 2      https://api.spotify.com/v1/audio-analysis/4Cee...      301920
# 3      https://api.spotify.com/v1/audio-analysis/7pKf...      187867
# 4      https://api.spotify.com/v1/audio-analysis/5Nwk...      302107
# ...                                                  ...         ...
# 12233  https://api.spotify.com/v1/audio-analysis/6Pd2...      271530
# 12234  https://api.spotify.com/v1/audio-analysis/0ORL...      258747
# 12235  https://api.spotify.com/v1/audio-analysis/58xN...      253711
# 12236  https://api.spotify.com/v1/audio-analysis/46mM...      233465
# 12237  https://api.spotify.com/v1/audio-analysis/2uRO...      225341
#
#       time_signature
# 0                  4
# 1                  4
# 2                  4
# 3                  4
# 4                  4
# ...              ...
# 12233              4
# 12234              4
# 12235              4
# 12236              5
# 12237              4
#
# [12238 rows x 22 columns]

# %%
df.to_csv("Data/clean_song_db", index=False)

# %% [markdown]
# ## Clustering

# %%
#importing libraries
import numpy as np
import pandas as pd
import pickle
from sklearn import datasets # sklearn comes with some toy datasets to practise
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from matplotlib import pyplot
from sklearn.metrics import silhouette_score

# %%
df.head()
# Out:
#    srno                                songs        artists  \
# 0     0  Bohemian Rhapsody - Remastered 2011          Queen
# 1     1                  Sweet Child O' Mine  Guns N' Roses
# 2     2              Smells Like Teen Spirit        Nirvana
# 3     3            Imagine - Remastered 2010    John Lennon
# 4     4                     You're the Voice   John Farnham
#
#                                    uris  danceability  energy  key  loudness  \
# 0  spotify:track:4u7EnebtmKWzUH433cf5Qv         0.414   0.404    0    -9.928
# 1  spotify:track:7o2CTH4ctstm8TNelqjb51         0.454   0.910    6    -7.766
# 2  spotify:track:4CeeEOM32jQcH3eN9Q2dGj         0.502   0.912    1    -4.556
# 3  spotify:track:7pKfPomDEeI4TPT6EOYjn9         0.547   0.257    0   -12.358
# 4  spotify:track:5NwkWwfRJaT55hEPtCmJHx         0.369   0.762   10    -8.993
#
#    mode  speechiness  ...  liveness  valence    tempo            type  \
# 0     0       0.0499  ...    0.3000    0.224   71.105  audio_features
# 1     1       0.0448  ...    0.1160    0.629  125.116  audio_features
# 2     1       0.0564  ...    0.1060    0.720  116.761  audio_features
# 3     1       0.0252  ...    0.0935    0.169   75.752  audio_features
# 4     1       0.0464  ...    0.5790    0.644   84.957  audio_features
#
#                        id                                   uri  \
# 0  4u7EnebtmKWzUH433cf5Qv  spotify:track:4u7EnebtmKWzUH433cf5Qv
# 1  7o2CTH4ctstm8TNelqjb51  spotify:track:7o2CTH4ctstm8TNelqjb51
# 2  4CeeEOM32jQcH3eN9Q2dGj  spotify:track:4CeeEOM32jQcH3eN9Q2dGj
# 3  7pKfPomDEeI4TPT6EOYjn9  spotify:track:7pKfPomDEeI4TPT6EOYjn9
# 4  5NwkWwfRJaT55hEPtCmJHx  spotify:track:5NwkWwfRJaT55hEPtCmJHx
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/4u7EnebtmKWz...
# 1  https://api.spotify.com/v1/tracks/7o2CTH4ctstm...
# 2  https://api.spotify.com/v1/tracks/4CeeEOM32jQc...
# 3  https://api.spotify.com/v1/tracks/7pKfPomDEeI4...
# 4  https://api.spotify.com/v1/tracks/5NwkWwfRJaT5...
#
#                                         analysis_url duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/4u7E...      354320
# 1  https://api.spotify.com/v1/audio-analysis/7o2C...      354520
# 2  https://api.spotify.com/v1/audio-analysis/4Cee...      301920
# 3  https://api.spotify.com/v1/audio-analysis/7pKf...      187867
# 4  https://api.spotify.com/v1/audio-analysis/5Nwk...      302107
#
#   time_signature
# 0              4
# 1              4
# 2              4
# 3              4
# 4              4
#
# [5 rows x 22 columns]

# %%
df.describe()
# Out:
#                srno  danceability        energy           key      loudness  \
# count  12238.000000  12238.000000  12238.000000  12238.000000  12238.000000
# mean    1556.544615      0.634941      0.688750      5.245955     -6.545166
# std     1456.209019      0.152516      0.191016      3.612420      3.040686
# min        0.000000      0.065700      0.018600      0.000000    -28.232000
# 25%      388.000000      0.535000      0.573000      2.000000     -7.707750
# 50%     1038.500000      0.648000      0.716000      5.000000     -5.877500
# 75%     2284.750000      0.745000      0.835000      8.000000     -4.535250
# max     5294.000000      0.988000      1.000000     11.000000      0.175000
#
#                mode   speechiness  acousticness  instrumentalness  \
# count  12238.000000  12238.000000  12238.000000      12238.000000
# mean       0.587106      0.091580      0.189406          0.029387
# std        0.492374      0.088797      0.239679          0.130342
# min        0.000000      0.022400      0.000002          0.000000
# 25%        0.000000      0.037700      0.016200          0.000000
# 50%        1.000000      0.055300      0.082500          0.000002
# 75%        1.000000      0.104000      0.271000          0.000291
# max        1.000000      0.925000      0.993000          0.987000
#
#            liveness       valence         tempo    duration_ms  time_signature
# count  12238.000000  12238.000000  12238.000000   12238.000000    12238.000000
# mean       0.187538      0.534037    121.163557  225823.113662        3.970420
# std        0.147926      0.234226     28.010225   54203.327225        0.245128
# min        0.012000      0.032000     39.497000   25260.000000        1.000000
# 25%        0.093300      0.350000     99.464250  194793.500000        4.000000
# 50%        0.129000      0.535000    120.021500  219192.500000        4.000000
# 75%        0.247000      0.722000    137.921000  249120.000000        4.000000
# max        0.994000      1.000000    214.016000  899933.000000        5.000000

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## Scaling

# %%
#dropping the categorical variables for scaling
X=df._get_numeric_data()

# %%
X
# Out:
#        srno  danceability  energy  key  loudness  mode  speechiness  \
# 0         0         0.414   0.404    0    -9.928     0       0.0499
# 1         1         0.454   0.910    6    -7.766     1       0.0448
# 2         2         0.502   0.912    1    -4.556     1       0.0564
# 3         3         0.547   0.257    0   -12.358     1       0.0252
# 4         4         0.369   0.762   10    -8.993     1       0.0464
# ...     ...           ...     ...  ...       ...   ...          ...
# 12233   665         0.666   0.537    8   -10.467     1       0.2490
# 12234   666         0.785   0.394    4    -8.010     1       0.0392
# 12235   667         0.836   0.678    5    -8.206     0       0.0990
# 12236   668         0.569   0.409    2   -10.612     1       0.0396
# 12237   669         0.785   0.367    4    -8.483     0       0.0363
#
#        acousticness  instrumentalness  liveness  valence    tempo  \
# 0          0.271000          0.000000    0.3000   0.2240   71.105
# 1          0.086600          0.099600    0.1160   0.6290  125.116
# 2          0.000025          0.000173    0.1060   0.7200  116.761
# 3          0.907000          0.183000    0.0935   0.1690   75.752
# 4          0.220000          0.000028    0.5790   0.6440   84.957
# ...             ...               ...       ...      ...      ...
# 12233      0.477000          0.020800    0.0656   0.6530   93.002
# 12234      0.572000          0.000801    0.1110   0.1310  100.002
# 12235      0.012600          0.002050    0.3690   0.6330  116.020
# 12236      0.059300          0.296000    0.0971   0.0948  118.028
# 12237      0.113000          0.063300    0.0902   0.4680   90.003
#
#        duration_ms  time_signature
# 0           354320               4
# 1           354520               4
# 2           301920               4
# 3           187867               4
# 4           302107               4
# ...            ...             ...
# 12233       271530               4
# 12234       258747               4
# 12235       253711               4
# 12236       233465               5
# 12237       225341               4
#
# [12238 rows x 14 columns]

# %%
scaler = StandardScaler()
scaler.fit(X)
X_scaled = scaler.transform(X)
X_scaled_df = pd.DataFrame(X_scaled, columns = X.columns)
display(X.head())
# Out:
#    srno  danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0     0         0.414   0.404    0    -9.928     0       0.0499      0.271000
# 1     1         0.454   0.910    6    -7.766     1       0.0448      0.086600
# 2     2         0.502   0.912    1    -4.556     1       0.0564      0.000025
# 3     3         0.547   0.257    0   -12.358     1       0.0252      0.907000
# 4     4         0.369   0.762   10    -8.993     1       0.0464      0.220000
#
#    instrumentalness  liveness  valence    tempo  duration_ms  time_signature
# 0          0.000000    0.3000    0.224   71.105       354320               4
# 1          0.099600    0.1160    0.629  125.116       354520               4
# 2          0.000173    0.1060    0.720  116.761       301920               4
# 3          0.183000    0.0935    0.169   75.752       187867               4
# 4          0.000028    0.5790    0.644   84.957       302107               4

# %%
X_scaled_df.describe()
# Out:
#                srno  danceability        energy           key      loudness  \
# count  1.223800e+04  1.223800e+04  1.223800e+04  1.223800e+04  1.223800e+04
# mean   8.566625e-17 -6.765847e-17 -9.525528e-17 -1.789030e-16 -5.326676e-16
# std    1.000041e+00  1.000041e+00  1.000041e+00  1.000041e+00  1.000041e+00
# min   -1.068946e+00 -3.732480e+00 -3.508492e+00 -1.452259e+00 -7.132510e+00
# 25%   -8.024894e-01 -6.553056e-01 -6.059967e-01 -8.985910e-01 -3.823583e-01
# 50%   -3.557633e-01  8.562921e-02  1.426628e-01 -6.808878e-02  2.195865e-01
# 75%    5.000897e-01  7.216529e-01  7.656731e-01  7.624134e-01  6.610346e-01
# max    2.566670e+00  2.314991e+00  1.629511e+00  1.592916e+00  2.210173e+00
#
#                mode   speechiness  acousticness  instrumentalness  \
# count  1.223800e+04  1.223800e+04  1.223800e+04      1.223800e+04
# mean   6.974683e-15  1.678307e-18  4.760360e-16     -1.203705e-15
# std    1.000041e+00  1.000041e+00  1.000041e+00      1.000041e+00
# min   -1.192446e+00 -7.791167e-01 -7.902733e-01     -2.254689e-01
# 25%   -1.192446e+00 -6.068059e-01 -7.226882e-01     -2.254689e-01
# 50%    8.386124e-01 -4.085922e-01 -4.460571e-01     -2.254510e-01
# 75%    8.386124e-01  1.398741e-01  3.404429e-01     -2.232362e-01
# max    8.386124e-01  9.386092e+00  3.352926e+00      7.347227e+00
#
#            liveness       valence         tempo   duration_ms  time_signature
# count  1.223800e+04  1.223800e+04  1.223800e+04  1.223800e+04    1.223800e+04
# mean  -6.189144e-16 -5.619427e-16 -1.910549e-16  1.894938e-16   -3.542225e-15
# std    1.000041e+00  1.000041e+00  1.000041e+00  1.000041e+00    1.000041e+00
# min   -1.186713e+00 -2.143471e+00 -2.915717e+00 -3.700350e+00   -1.211834e+01
# 25%   -6.370896e-01 -7.857552e-01 -7.747240e-01 -5.724903e-01    1.206767e-01
# 50%   -3.957423e-01  4.111193e-03 -4.077454e-02 -1.223335e-01    1.206767e-01
# 75%    4.019885e-01  8.025167e-01  5.982861e-01  4.298230e-01    1.206767e-01
# max    5.452030e+00  1.989451e+00  3.315084e+00  1.243720e+01    4.200349e+00

# %%
#randomly picked 9 clusters
kmeans = KMeans(n_clusters=8, random_state=1234)
kmeans.fit(X_scaled_df)
# Out:
# KMeans(random_state=1234)

# %%
X_scaled_df
# Out:
#            srno  danceability    energy       key  loudness      mode  \
# 0     -1.068946     -1.448696 -1.490776 -1.452259 -1.112569 -1.192446
# 1     -1.068259     -1.186418  1.158327  0.208745 -0.401516  0.838612
# 2     -1.067572     -0.871685  1.168797 -1.175425  0.654210  0.838612
# 3     -1.066885     -0.576622 -2.260377 -1.452259 -1.911763  0.838612
# 4     -1.066199     -1.743758  0.383490  1.316082 -0.805060  0.838612
# ...         ...           ...       ...       ...       ...       ...
# 12233 -0.612262      0.203654 -0.794470  0.762413 -1.289839  0.838612
# 12234 -0.611575      0.983931 -1.543130 -0.344923 -0.481764  0.838612
# 12235 -0.610888      1.318335 -0.056282 -0.068089 -0.546226 -1.192446
# 12236 -0.610201     -0.432369 -1.464599 -0.898591 -1.337527  0.838612
# 12237 -0.609515      0.983931 -1.684485 -0.344923 -0.637328 -1.192446
#
#        speechiness  acousticness  instrumentalness  liveness   valence  \
# 0        -0.469408      0.340443         -0.225469  0.760291 -1.323718
# 1        -0.526845     -0.428950          0.538706 -0.483628  0.405449
# 2        -0.396204     -0.790175         -0.224142 -0.551232  0.793978
# 3        -0.747583      2.994098          1.178587 -0.635738 -1.558543
# 4        -0.508825      0.127650         -0.225254  2.646451  0.469492
# ...            ...           ...               ...       ...       ...
# 12233     1.772885      1.199960         -0.065882 -0.824354  0.507918
# 12234    -0.589913      1.596340         -0.219323 -0.517430 -1.720786
# 12235     0.083563     -0.737709         -0.209740  1.226761  0.422527
# 12236    -0.585408     -0.542857          2.045573 -0.611400 -1.875344
# 12237    -0.622573     -0.318799          0.260196 -0.658047 -0.281949
#
#           tempo  duration_ms  time_signature
# 0     -1.787226     2.370743        0.120677
# 1      0.141113     2.374433        0.120677
# 2     -0.157183     1.403973        0.120677
# 3     -1.621316    -0.700283        0.120677
# 4     -1.292672     1.407423        0.120677
# ...         ...          ...             ...
# 12233 -1.005444     0.843283        0.120677
# 12234 -0.755525     0.607439        0.120677
# 12235 -0.183639     0.514526        0.120677
# 12236 -0.111948     0.140991        4.200349
# 12237 -1.112516    -0.008895        0.120677
#
# [12238 rows x 14 columns]

# %%
len(kmeans.labels_)
# Out:
# 12238

# %%
# assign a cluster to each example
labels = kmeans.predict(X_scaled_df)
# retrieve unique clusters
clusters = np.unique(labels)
# create scatter plot for samples from each cluster
for cluster in clusters:
    # get row indexes for samples with this cluster
    row_ix = np.where(labels == cluster)
    # create scatter of these samples
    pyplot.scatter(X.to_numpy()[row_ix, 1], X.to_numpy()[row_ix, 2])
    # show the plot
pyplot.show()

# %%
clusters = kmeans.predict(X_scaled_df)
#clusters
pd.Series(clusters).value_counts().sort_index()
# Out:
# 0    10590
# 1      992
# 2      344
# 3      230
# 4      368
# 5      100
# dtype: int64

# %%
#X_df = pd.DataFrame(X)
X["cluster"] = clusters
X.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.762   0.766    7    -3.955     1       0.0343       0.00776
# 1         0.762   0.766    7    -3.955     1       0.0343       0.00776
# 2         0.762   0.766    7    -3.955     1       0.0343       0.00776
# 3         0.762   0.766    7    -3.955     1       0.0343       0.00776
# 4         0.762   0.766    7    -3.955     1       0.0343       0.00776
#
#    instrumentalness  liveness  valence    tempo  duration_ms  time_signature  \
# 0           0.00007     0.128    0.442  130.001       287120               4
# 1           0.00007     0.128    0.442  130.001       287120               4
# 2           0.00007     0.128    0.442  130.001       287120               4
# 3           0.00007     0.128    0.442  130.001       287120               4
# 4           0.00007     0.128    0.442  130.001       287120               4
#
#    cluster
# 0        5
# 1        5
# 2        5
# 3        5
# 4        5

# %%
X[X['cluster'] == 2].sample()
# Out:
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 12217         0.852   0.773    8    -2.921     0       0.0776         0.187
#
#        instrumentalness  liveness  valence    tempo  duration_ms  \
# 12217           0.00003     0.159    0.907  102.034       195840
#
#        time_signature  cluster
# 12217               4        2

# %%
kmeans.inertia_
# Out:
# 1.6052590278807713e-23

# %%
kmeans2 = KMeans(n_clusters=50,
                init="k-means++",
                n_init=50,  # try with 1, 4, 8, 20, 30, 100...
                max_iter=10,
                tol=0,
                algorithm="elkan",
                random_state=1234)
kmeans2.fit(X_scaled_df)
print(kmeans2.inertia_)
# Out:
# 1.4364753691884797e-23
# <ipython-input-85-f66d17318bd7>:8: ConvergenceWarning: Number of distinct clusters (6) found smaller than n_clusters (50). Possibly due to duplicate points in X.
#   kmeans2.fit(X_scaled_df)

# %%
K = range(2, 21)
inertia = []

for k in K:
    print("Training a K-Means model with {} clusters! ".format(k))
    print()
    kmeans = KMeans(n_clusters=k,
                    random_state=1234)
    kmeans.fit(X_scaled_df)
    inertia.append(kmeans.inertia_)

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(16,8))
plt.plot(K, inertia, 'bx-')
plt.xlabel('k')
plt.ylabel('inertia')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.title('Elbow Method showing the optimal k')
# Out:
# Training a K-Means model with 2 clusters!
#
# Training a K-Means model with 3 clusters!
#
# Training a K-Means model with 4 clusters!
#
# Training a K-Means model with 5 clusters!
#
# Training a K-Means model with 6 clusters!
#
# Training a K-Means model with 7 clusters!
# <ipython-input-86-1440c493a442>:9: ConvergenceWarning: Number of distinct clusters (6) found smaller than n_clusters (7). Possibly due to duplicate points in X.
#   kmeans.fit(X_scaled_df)
# Training a K-Means model with 8 clusters!
# <ipython-input-86-1440c493a442>:9: ConvergenceWarning: Number of distinct clusters (6) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   kmeans.fit(X_scaled_df)
# Training a K-Means model with 9 clusters!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\numpy\core\_methods.py in _sum(a, axis, dtype, out, keepdims, initial, where)
#      43     return umr_minimum(a, axis, None, out, keepdims, initial, where)
#      44
# ---> 45 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      46          initial=_NoValue, where=True):
#      47     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#
# KeyboardInterrupt:
# Exception ignored in: 'sklearn.cluster._k_means_fast._relocate_empty_clusters_dense'
# Traceback (most recent call last):
#   File "C:\Users\Harutyunyan\anaconda3\lib\site-packages\numpy\core\_methods.py", line 45, in _sum
#     def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-86-1440c493a442> in <module>
#       7     kmeans = KMeans(n_clusters=k,
#       8                     random_state=1234)
# ----> 9     kmeans.fit(X_scaled_df)
#      10     inertia.append(kmeans.inertia_)
#      11
#
# ~\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py in fit(self, X, y, sample_weight)
#    1021
#    1022             # run a k-means once
# -> 1023             labels, inertia, centers, n_iter_ = kmeans_single(
#    1024                 X, sample_weight, centers_init, max_iter=self.max_iter,
#    1025                 verbose=self.verbose, tol=self._tol,
#
# ~\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py in _kmeans_single_elkan(X, sample_weight, centers_init, max_iter, verbose, x_squared_norms, tol, n_threads)
#     391         # center of each center for next iterations
#     392         center_half_distances = euclidean_distances(centers_new) / 2
# --> 393         distance_next_center = np.partition(
#     394             np.asarray(center_half_distances), kth=1, axis=0)[1]
#     395
#
# <__array_function__ internals> in partition(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\core\fromnumeric.py in partition(a, kth, axis, kind, order)
#     750         axis = -1
#     751     else:
# --> 752         a = asanyarray(a).copy(order="K")
#     753     a.partition(kth, axis=axis, kind=kind, order=order)
#     754     return a
#
# KeyboardInterrupt:

# %%
K = range(2, 20)
silhouette = []

for k in K:
    kmeans = KMeans(n_clusters=k,
                    random_state=1234)
    kmeans.fit(X_scaled_df)
    
    filename = "Model/kmeans_" + str(k) + ".pickle"
    with open(filename, "wb") as f:
        pickle.dump(kmeans,f)
    
    silhouette.append(silhouette_score(X_scaled_df, kmeans.predict(X_scaled_df)))


plt.figure(figsize=(16,8))
plt.plot(K, silhouette, 'bx-')
plt.xlabel('k')
plt.ylabel('silhouette score')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.title('Silhouette Method showing the optimal k')

# %%
from yellowbrick.cluster import SilhouetteVisualizer
model = KMeans(3, random_state=42)
visualizer = SilhouetteVisualizer(model, colors='yellowbrick')
visualizer.fit(X_scaled_df)        # Fit the data to the visualizer
visualizer.show()        # Finalize and render the figure
