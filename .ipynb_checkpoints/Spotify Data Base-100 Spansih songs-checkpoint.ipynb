# %% [markdown]
# # Spotify DataBase

# %%
#We import the credential
import config
import pandas as pd
from time import sleep
from random import randint

# %%
#import the libraries we need 
import spotipy
import json
from spotipy.oauth2 import SpotifyClientCredentials

# %%
#Initialize SpotiPy with user credentias

sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=config.client_id,
                                                           client_secret=config.client_secret))

# %%
# We are going to extract the songs of the playlist:100 Spanish Songs 2021 (https://open.spotify.com/playlist/16hxSUyO5wrVonerHzytOv)

playlist = sp.user_playlist_tracks("spotify", "16hxSUyO5wrVonerHzytOv",market="GB")

# %%
# we confirm the number of songs of our playlist. We have 10000 songs
print(list(playlist.keys())) # Let's look at items and total:
print("Total number of songs in the playlist: ",playlist["total"]) # 4Ksongs!! Let's check items:
len(playlist["items"])
# Out:
# ['href', 'items', 'limit', 'next', 'offset', 'previous', 'total']
# Total number of songs in the playlist:  100
# 100

# %%
def get_playlist_tracks(username, playlist_id):
    results = sp.user_playlist_tracks(username,playlist_id,market="GB")
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

# %%
track=get_playlist_tracks("spotify","16hxSUyO5wrVonerHzytOv")

# %%
track[0]
# Out:
# {'added_at': '2021-09-18T02:14:13Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/redmusiccompany'},
#   'href': 'https://api.spotify.com/v1/users/redmusiccompany',
#   'id': 'redmusiccompany',
#   'type': 'user',
#   'uri': 'spotify:user:redmusiccompany'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'album': {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/329e4yvIujISKGKz1BZZbO'},
#      'href': 'https://api.spotify.com/v1/artists/329e4yvIujISKGKz1BZZbO',
#      'id': '329e4yvIujISKGKz1BZZbO',
#      'name': 'Farruko',
#      'type': 'artist',
#      'uri': 'spotify:artist:329e4yvIujISKGKz1BZZbO'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/2A5ksnhz7YWbRLvFMjX1j1'},
#    'href': 'https://api.spotify.com/v1/albums/2A5ksnhz7YWbRLvFMjX1j1',
#    'id': '2A5ksnhz7YWbRLvFMjX1j1',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273c77a01f0166fd8343d3a3edb',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02c77a01f0166fd8343d3a3edb',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851c77a01f0166fd8343d3a3edb',
#      'width': 64}],
#    'name': 'Pepas',
#    'release_date': '2021-06-24',
#    'release_date_precision': 'day',
#    'total_tracks': 1,
#    'type': 'album',
#    'uri': 'spotify:album:2A5ksnhz7YWbRLvFMjX1j1'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/329e4yvIujISKGKz1BZZbO'},
#     'href': 'https://api.spotify.com/v1/artists/329e4yvIujISKGKz1BZZbO',
#     'id': '329e4yvIujISKGKz1BZZbO',
#     'name': 'Farruko',
#     'type': 'artist',
#     'uri': 'spotify:artist:329e4yvIujISKGKz1BZZbO'}],
#   'disc_number': 1,
#   'duration_ms': 287120,
#   'episode': False,
#   'explicit': True,
#   'external_ids': {'isrc': 'USSD12100307'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/5fwSHlTEWpluwOM0Sxnh5k'},
#   'href': 'https://api.spotify.com/v1/tracks/5fwSHlTEWpluwOM0Sxnh5k',
#   'id': '5fwSHlTEWpluwOM0Sxnh5k',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Pepas',
#   'popularity': 94,
#   'preview_url': 'https://p.scdn.co/mp3-preview/890f6034cf93d666d0f89d5724430c6ddd276eb2?cid=a843084989cb436bbdfd08d8cc884673',
#   'track': True,
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:5fwSHlTEWpluwOM0Sxnh5k'},
#  'video_thumbnail': {'url': None}}

# %% [markdown]
# # Getting the songs and the artists of the playlist

# %%
# How we get the song
track[0]["track"]["name"]
# Out:
# 'Pepas'

# %%
# how we get the artist
track[0]["track"]["artists"][0]["name"]
# Out:
# 'Farruko'

# %%
track[0]["track"]["uri"]
# Out:
# 'spotify:track:5fwSHlTEWpluwOM0Sxnh5k'

# %%
# function to get the songs and artist
songs=[]
artists=[]
uri=[]

for i in range(len(track)):
    uri.append(track[0]["track"]["uri"])
    songs.append(track[i]["track"]["name"])
    artists.append(track[i]["track"]["artists"][0]["name"])

# %%
uri
# Out:
# ['spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'spotify:track:5fwSHlTEWpluwOM0Sxnh5k']

# %% [markdown]
# # Get the most important features

# %%
sp.audio_features(track[0]["track"]["uri"])
# Out:
# [{'danceability': 0.762,
#   'energy': 0.766,
#   'key': 7,
#   'loudness': -3.955,
#   'mode': 1,
#   'speechiness': 0.0343,
#   'acousticness': 0.00776,
#   'instrumentalness': 6.98e-05,
#   'liveness': 0.128,
#   'valence': 0.442,
#   'tempo': 130.001,
#   'type': 'audio_features',
#   'id': '5fwSHlTEWpluwOM0Sxnh5k',
#   'uri': 'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#   'track_href': 'https://api.spotify.com/v1/tracks/5fwSHlTEWpluwOM0Sxnh5k',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5fwSHlTEWpluwOM0Sxnh5k',
#   'duration_ms': 287120,
#   'time_signature': 4}]

# %%
df_song_artist=pd.DataFrame({"songs":songs,"artists":artists,"uri":uri})

# %%
df_song_artist
# Out:
#                   songs         artists                                   uri
# 0                 Pepas         Farruko  spotify:track:5fwSHlTEWpluwOM0Sxnh5k
# 1                 Volví        Aventura  spotify:track:5fwSHlTEWpluwOM0Sxnh5k
# 2              Yonaguni       Bad Bunny  spotify:track:5fwSHlTEWpluwOM0Sxnh5k
# 3             Invisible           Andra  spotify:track:5fwSHlTEWpluwOM0Sxnh5k
# 4            Todo De Ti  Rauw Alejandro  spotify:track:5fwSHlTEWpluwOM0Sxnh5k
# ..                  ...             ...                                   ...
# 95            Si Te Veo        Arcangel  spotify:track:5fwSHlTEWpluwOM0Sxnh5k
# 96      En la Oscuridad      LIT killah  spotify:track:5fwSHlTEWpluwOM0Sxnh5k
# 97   Bailando Te Conocí      Rusherking  spotify:track:5fwSHlTEWpluwOM0Sxnh5k
# 98  23 (With Ape Drums)           Randy  spotify:track:5fwSHlTEWpluwOM0Sxnh5k
# 99     Cuando Ella Sale           Morad  spotify:track:5fwSHlTEWpluwOM0Sxnh5k
#
# [100 rows x 3 columns]

# %%
song = sp.search(q="pepas", limit=1) 
#pprint.pprint(song['tracks']['items'][0]['uri'])
song["tracks"]["items"][0]["uri"]
sp.audio_features(song["tracks"]["items"][0]["uri"])[0]
# Out:
# {'danceability': 0.762,
#  'energy': 0.766,
#  'key': 7,
#  'loudness': -3.955,
#  'mode': 1,
#  'speechiness': 0.0343,
#  'acousticness': 0.00776,
#  'instrumentalness': 6.98e-05,
#  'liveness': 0.128,
#  'valence': 0.442,
#  'tempo': 130.001,
#  'type': 'audio_features',
#  'id': '5fwSHlTEWpluwOM0Sxnh5k',
#  'uri': 'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'track_href': 'https://api.spotify.com/v1/tracks/5fwSHlTEWpluwOM0Sxnh5k',
#  'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5fwSHlTEWpluwOM0Sxnh5k',
#  'duration_ms': 287120,
#  'time_signature': 4}

# %%
features=[]

for i in range(len(track)):
    if i%50==0:
        seconds_to_wait = randint(0,1)
        print("Wating {} seconds before scraping the next website!".format(seconds_to_wait))
        sleep(seconds_to_wait)
    
    feature= sp.audio_features(uri[i])
    features.append(feature)
# Out:
# Wating 1 seconds before scraping the next website!
# Wating 0 seconds before scraping the next website!

# %%
features[1][0]
# Out:
# {'danceability': 0.762,
#  'energy': 0.766,
#  'key': 7,
#  'loudness': -3.955,
#  'mode': 1,
#  'speechiness': 0.0343,
#  'acousticness': 0.00776,
#  'instrumentalness': 6.98e-05,
#  'liveness': 0.128,
#  'valence': 0.442,
#  'tempo': 130.001,
#  'type': 'audio_features',
#  'id': '5fwSHlTEWpluwOM0Sxnh5k',
#  'uri': 'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'track_href': 'https://api.spotify.com/v1/tracks/5fwSHlTEWpluwOM0Sxnh5k',
#  'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5fwSHlTEWpluwOM0Sxnh5k',
#  'duration_ms': 287120,
#  'time_signature': 4}

# %%
data=[]
df2=pd.DataFrame(features)
df2=df2[0]
df2
# Out:
# 0     {'danceability': 0.762, 'energy': 0.766, 'key'...
# 1     {'danceability': 0.762, 'energy': 0.766, 'key'...
# 2     {'danceability': 0.762, 'energy': 0.766, 'key'...
# 3     {'danceability': 0.762, 'energy': 0.766, 'key'...
# 4     {'danceability': 0.762, 'energy': 0.766, 'key'...
#                             ...
# 95    {'danceability': 0.762, 'energy': 0.766, 'key'...
# 96    {'danceability': 0.762, 'energy': 0.766, 'key'...
# 97    {'danceability': 0.762, 'energy': 0.766, 'key'...
# 98    {'danceability': 0.762, 'energy': 0.766, 'key'...
# 99    {'danceability': 0.762, 'energy': 0.766, 'key'...
# Name: 0, Length: 100, dtype: object

# %%
data=[]
df3= pd.DataFrame(data,columns=["danceability","energy","key","loudness","mode","speechiness","acousticness","instrumentalness","liveness"
,"valence","tempo","type","id","uri","track_href","analysis_url","duration_ms","time_signature"])

# %%
for i in range(len(features)):
    df3= df3.append(df2[i],ignore_index=True)

# %%
spotify_data= pd.concat([df_song_artist, df3],axis=1).reset_index(drop=True)
spotify_data
# Out:
#                   songs         artists                                   uri  \
# 0                 Pepas         Farruko  spotify:track:5fwSHlTEWpluwOM0Sxnh5k
# 1                 Volví        Aventura  spotify:track:5fwSHlTEWpluwOM0Sxnh5k
# 2              Yonaguni       Bad Bunny  spotify:track:5fwSHlTEWpluwOM0Sxnh5k
# 3             Invisible           Andra  spotify:track:5fwSHlTEWpluwOM0Sxnh5k
# 4            Todo De Ti  Rauw Alejandro  spotify:track:5fwSHlTEWpluwOM0Sxnh5k
# ..                  ...             ...                                   ...
# 95            Si Te Veo        Arcangel  spotify:track:5fwSHlTEWpluwOM0Sxnh5k
# 96      En la Oscuridad      LIT killah  spotify:track:5fwSHlTEWpluwOM0Sxnh5k
# 97   Bailando Te Conocí      Rusherking  spotify:track:5fwSHlTEWpluwOM0Sxnh5k
# 98  23 (With Ape Drums)           Randy  spotify:track:5fwSHlTEWpluwOM0Sxnh5k
# 99     Cuando Ella Sale           Morad  spotify:track:5fwSHlTEWpluwOM0Sxnh5k
#
#     danceability  energy key  loudness mode  speechiness  acousticness  ...  \
# 0          0.762   0.766   7    -3.955    1       0.0343       0.00776  ...
# 1          0.762   0.766   7    -3.955    1       0.0343       0.00776  ...
# 2          0.762   0.766   7    -3.955    1       0.0343       0.00776  ...
# 3          0.762   0.766   7    -3.955    1       0.0343       0.00776  ...
# 4          0.762   0.766   7    -3.955    1       0.0343       0.00776  ...
# ..           ...     ...  ..       ...  ...          ...           ...  ...
# 95         0.762   0.766   7    -3.955    1       0.0343       0.00776  ...
# 96         0.762   0.766   7    -3.955    1       0.0343       0.00776  ...
# 97         0.762   0.766   7    -3.955    1       0.0343       0.00776  ...
# 98         0.762   0.766   7    -3.955    1       0.0343       0.00776  ...
# 99         0.762   0.766   7    -3.955    1       0.0343       0.00776  ...
#
#     liveness  valence    tempo            type                      id  \
# 0      0.128    0.442  130.001  audio_features  5fwSHlTEWpluwOM0Sxnh5k
# 1      0.128    0.442  130.001  audio_features  5fwSHlTEWpluwOM0Sxnh5k
# 2      0.128    0.442  130.001  audio_features  5fwSHlTEWpluwOM0Sxnh5k
# 3      0.128    0.442  130.001  audio_features  5fwSHlTEWpluwOM0Sxnh5k
# 4      0.128    0.442  130.001  audio_features  5fwSHlTEWpluwOM0Sxnh5k
# ..       ...      ...      ...             ...                     ...
# 95     0.128    0.442  130.001  audio_features  5fwSHlTEWpluwOM0Sxnh5k
# 96     0.128    0.442  130.001  audio_features  5fwSHlTEWpluwOM0Sxnh5k
# 97     0.128    0.442  130.001  audio_features  5fwSHlTEWpluwOM0Sxnh5k
# 98     0.128    0.442  130.001  audio_features  5fwSHlTEWpluwOM0Sxnh5k
# 99     0.128    0.442  130.001  audio_features  5fwSHlTEWpluwOM0Sxnh5k
#
#                                      uri  \
# 0   spotify:track:5fwSHlTEWpluwOM0Sxnh5k
# 1   spotify:track:5fwSHlTEWpluwOM0Sxnh5k
# 2   spotify:track:5fwSHlTEWpluwOM0Sxnh5k
# 3   spotify:track:5fwSHlTEWpluwOM0Sxnh5k
# 4   spotify:track:5fwSHlTEWpluwOM0Sxnh5k
# ..                                   ...
# 95  spotify:track:5fwSHlTEWpluwOM0Sxnh5k
# 96  spotify:track:5fwSHlTEWpluwOM0Sxnh5k
# 97  spotify:track:5fwSHlTEWpluwOM0Sxnh5k
# 98  spotify:track:5fwSHlTEWpluwOM0Sxnh5k
# 99  spotify:track:5fwSHlTEWpluwOM0Sxnh5k
#
#                                            track_href  \
# 0   https://api.spotify.com/v1/tracks/5fwSHlTEWplu...
# 1   https://api.spotify.com/v1/tracks/5fwSHlTEWplu...
# 2   https://api.spotify.com/v1/tracks/5fwSHlTEWplu...
# 3   https://api.spotify.com/v1/tracks/5fwSHlTEWplu...
# 4   https://api.spotify.com/v1/tracks/5fwSHlTEWplu...
# ..                                                ...
# 95  https://api.spotify.com/v1/tracks/5fwSHlTEWplu...
# 96  https://api.spotify.com/v1/tracks/5fwSHlTEWplu...
# 97  https://api.spotify.com/v1/tracks/5fwSHlTEWplu...
# 98  https://api.spotify.com/v1/tracks/5fwSHlTEWplu...
# 99  https://api.spotify.com/v1/tracks/5fwSHlTEWplu...
#
#                                          analysis_url duration_ms  \
# 0   https://api.spotify.com/v1/audio-analysis/5fwS...      287120
# 1   https://api.spotify.com/v1/audio-analysis/5fwS...      287120
# 2   https://api.spotify.com/v1/audio-analysis/5fwS...      287120
# 3   https://api.spotify.com/v1/audio-analysis/5fwS...      287120
# 4   https://api.spotify.com/v1/audio-analysis/5fwS...      287120
# ..                                                ...         ...
# 95  https://api.spotify.com/v1/audio-analysis/5fwS...      287120
# 96  https://api.spotify.com/v1/audio-analysis/5fwS...      287120
# 97  https://api.spotify.com/v1/audio-analysis/5fwS...      287120
# 98  https://api.spotify.com/v1/audio-analysis/5fwS...      287120
# 99  https://api.spotify.com/v1/audio-analysis/5fwS...      287120
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4
# ..            ...
# 95              4
# 96              4
# 97              4
# 98              4
# 99              4
#
# [100 rows x 21 columns]

# %%
spotify_data.to_csv("Data/hot100_Spanish_songs.csv",index=False)
