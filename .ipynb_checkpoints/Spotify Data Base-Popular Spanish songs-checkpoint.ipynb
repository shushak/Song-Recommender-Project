# %% [markdown]
# # Spotify DataBase

# %%
#We import the credential
import config
import pandas as pd
from time import sleep
from random import randint

# %%
#import the libraries we need 
import spotipy
import json
from spotipy.oauth2 import SpotifyClientCredentials

# %%
#Initialize SpotiPy with user credentias

sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=config.client_id,
                                                           client_secret=config.client_secret))

# %%
# We are going to extract the songs of the playlist:popular Spanish songs (https://open.spotify.com/playlist/6d3rrS6KZwvV7XAqn82iJM)

playlist = sp.user_playlist_tracks("spotify", "6d3rrS6KZwvV7XAqn82iJM",market="GB")

# %%
# we confirm the number of songs of our playlist. We have 10000 songs
print(list(playlist.keys())) # Let's look at items and total:
print("Total number of songs in the playlist: ",playlist["total"]) # 4Ksongs!! Let's check items:
len(playlist["items"])
# Out:
# ['href', 'items', 'limit', 'next', 'offset', 'previous', 'total']
# Total number of songs in the playlist:  344
# 100

# %%
def get_playlist_tracks(username, playlist_id):
    results = sp.user_playlist_tracks(username,playlist_id,market="GB")
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

# %%
track=get_playlist_tracks("spotify","6d3rrS6KZwvV7XAqn82iJM")

# %%
track[0]
# Out:
# {'added_at': '2018-01-03T16:49:50Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/angiesaaan'},
#   'href': 'https://api.spotify.com/v1/users/angiesaaan',
#   'id': 'angiesaaan',
#   'type': 'user',
#   'uri': 'spotify:user:angiesaaan'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0EmeFodog0BfCgMzAIvKQp'},
#      'href': 'https://api.spotify.com/v1/artists/0EmeFodog0BfCgMzAIvKQp',
#      'id': '0EmeFodog0BfCgMzAIvKQp',
#      'name': 'Shakira',
#      'type': 'artist',
#      'uri': 'spotify:artist:0EmeFodog0BfCgMzAIvKQp'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/6bUxh58rYTL67FS8dyTKMN'},
#    'href': 'https://api.spotify.com/v1/albums/6bUxh58rYTL67FS8dyTKMN',
#    'id': '6bUxh58rYTL67FS8dyTKMN',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273d05d3aad30c5fb7614893cf5',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02d05d3aad30c5fb7614893cf5',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851d05d3aad30c5fb7614893cf5',
#      'width': 64}],
#    'name': 'El Dorado',
#    'release_date': '2017-05-26',
#    'release_date_precision': 'day',
#    'total_tracks': 13,
#    'type': 'album',
#    'uri': 'spotify:album:6bUxh58rYTL67FS8dyTKMN'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0EmeFodog0BfCgMzAIvKQp'},
#     'href': 'https://api.spotify.com/v1/artists/0EmeFodog0BfCgMzAIvKQp',
#     'id': '0EmeFodog0BfCgMzAIvKQp',
#     'name': 'Shakira',
#     'type': 'artist',
#     'uri': 'spotify:artist:0EmeFodog0BfCgMzAIvKQp'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/1r4hJ1h58CWwUQe3MxPuau'},
#     'href': 'https://api.spotify.com/v1/artists/1r4hJ1h58CWwUQe3MxPuau',
#     'id': '1r4hJ1h58CWwUQe3MxPuau',
#     'name': 'Maluma',
#     'type': 'artist',
#     'uri': 'spotify:artist:1r4hJ1h58CWwUQe3MxPuau'}],
#   'disc_number': 1,
#   'duration_ms': 195840,
#   'episode': False,
#   'explicit': False,
#   'external_ids': {'isrc': 'USSD11600299'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/6mICuAdrwEjh6Y6lroV2Kg'},
#   'href': 'https://api.spotify.com/v1/tracks/6mICuAdrwEjh6Y6lroV2Kg',
#   'id': '6mICuAdrwEjh6Y6lroV2Kg',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Chantaje (feat. Maluma)',
#   'popularity': 74,
#   'preview_url': 'https://p.scdn.co/mp3-preview/ed23bf0d09f3589f4b0de7663f91e05e1eb95f6c?cid=a843084989cb436bbdfd08d8cc884673',
#   'track': True,
#   'track_number': 3,
#   'type': 'track',
#   'uri': 'spotify:track:6mICuAdrwEjh6Y6lroV2Kg'},
#  'video_thumbnail': {'url': None}}

# %% [markdown]
# # Getting the songs and the artists of the playlist

# %%
# How we get the song
track[0]["track"]["name"]
# Out:
# 'Chantaje (feat. Maluma)'

# %%
# how we get the artist
track[0]["track"]["artists"][0]["name"]
# Out:
# 'Shakira'

# %%
track[0]["track"]["uri"]
# Out:
# 'spotify:track:6mICuAdrwEjh6Y6lroV2Kg'

# %%
# function to get the songs and artist
songs=[]
artists=[]
uri=[]

for i in range(len(track)):
    uri.append(track[0]["track"]["uri"])
    songs.append(track[i]["track"]["name"])
    artists.append(track[i]["track"]["artists"][0]["name"])

# %%
uri
# Out:
# ['spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'spotify:track:6mICuAdrwEjh6Y6lroV2Kg']

# %% [markdown]
# # Get the most important features

# %%
sp.audio_features(track[0]["track"]["uri"])
# Out:
# [{'danceability': 0.852,
#   'energy': 0.773,
#   'key': 8,
#   'loudness': -2.921,
#   'mode': 0,
#   'speechiness': 0.0776,
#   'acousticness': 0.187,
#   'instrumentalness': 3.05e-05,
#   'liveness': 0.159,
#   'valence': 0.907,
#   'tempo': 102.034,
#   'type': 'audio_features',
#   'id': '6mICuAdrwEjh6Y6lroV2Kg',
#   'uri': 'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#   'track_href': 'https://api.spotify.com/v1/tracks/6mICuAdrwEjh6Y6lroV2Kg',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6mICuAdrwEjh6Y6lroV2Kg',
#   'duration_ms': 195840,
#   'time_signature': 4}]

# %%
df_song_artist=pd.DataFrame({"songs":songs,"artists":artists,"uri":uri})

# %%
df_song_artist
# Out:
#                                                  songs        artists  \
# 0                              Chantaje (feat. Maluma)        Shakira
# 1                                             Mi Gente       J Balvin
# 2                                        Felices los 4         Maluma
# 3                           Reggaetón Lento (Bailemos)           CNCO
# 4                                           Ahora Dice     Chris Jedi
# ..                                                 ...            ...
# 339                                           Bichiyal      Bad Bunny
# 340  La Curiosidad (feat. Dj Nelson, Jhay Cortez, L...    Jay Wheeler
# 341                                         EL MAKINON        KAROL G
# 342                                           AM Remix     Nio Garcia
# 343                                        Cosas Malas  Manuel Turizo
#
#                                       uri
# 0    spotify:track:6mICuAdrwEjh6Y6lroV2Kg
# 1    spotify:track:6mICuAdrwEjh6Y6lroV2Kg
# 2    spotify:track:6mICuAdrwEjh6Y6lroV2Kg
# 3    spotify:track:6mICuAdrwEjh6Y6lroV2Kg
# 4    spotify:track:6mICuAdrwEjh6Y6lroV2Kg
# ..                                    ...
# 339  spotify:track:6mICuAdrwEjh6Y6lroV2Kg
# 340  spotify:track:6mICuAdrwEjh6Y6lroV2Kg
# 341  spotify:track:6mICuAdrwEjh6Y6lroV2Kg
# 342  spotify:track:6mICuAdrwEjh6Y6lroV2Kg
# 343  spotify:track:6mICuAdrwEjh6Y6lroV2Kg
#
# [344 rows x 3 columns]

# %%
song = sp.search(q="pepas", limit=1) 
#pprint.pprint(song['tracks']['items'][0]['uri'])
song["tracks"]["items"][0]["uri"]
sp.audio_features(song["tracks"]["items"][0]["uri"])[0]
# Out:
# {'danceability': 0.762,
#  'energy': 0.766,
#  'key': 7,
#  'loudness': -3.955,
#  'mode': 1,
#  'speechiness': 0.0343,
#  'acousticness': 0.00776,
#  'instrumentalness': 6.98e-05,
#  'liveness': 0.128,
#  'valence': 0.442,
#  'tempo': 130.001,
#  'type': 'audio_features',
#  'id': '5fwSHlTEWpluwOM0Sxnh5k',
#  'uri': 'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'track_href': 'https://api.spotify.com/v1/tracks/5fwSHlTEWpluwOM0Sxnh5k',
#  'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5fwSHlTEWpluwOM0Sxnh5k',
#  'duration_ms': 287120,
#  'time_signature': 4}

# %%
features=[]

for i in range(len(track)):
    if i%50==0:
        seconds_to_wait = randint(0,1)
        print("Wating {} seconds before scraping the next website!".format(seconds_to_wait))
        sleep(seconds_to_wait)
    
    feature= sp.audio_features(uri[i])
    features.append(feature)
# Out:
# Wating 0 seconds before scraping the next website!
# Wating 0 seconds before scraping the next website!
# Wating 1 seconds before scraping the next website!
# Wating 1 seconds before scraping the next website!
# Wating 1 seconds before scraping the next website!
# Wating 0 seconds before scraping the next website!
# Wating 1 seconds before scraping the next website!

# %%
features[1][0]
# Out:
# {'danceability': 0.852,
#  'energy': 0.773,
#  'key': 8,
#  'loudness': -2.921,
#  'mode': 0,
#  'speechiness': 0.0776,
#  'acousticness': 0.187,
#  'instrumentalness': 3.05e-05,
#  'liveness': 0.159,
#  'valence': 0.907,
#  'tempo': 102.034,
#  'type': 'audio_features',
#  'id': '6mICuAdrwEjh6Y6lroV2Kg',
#  'uri': 'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'track_href': 'https://api.spotify.com/v1/tracks/6mICuAdrwEjh6Y6lroV2Kg',
#  'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6mICuAdrwEjh6Y6lroV2Kg',
#  'duration_ms': 195840,
#  'time_signature': 4}

# %%
data=[]
df2=pd.DataFrame(features)
df2=df2[0]
df2
# Out:
# 0      {'danceability': 0.852, 'energy': 0.773, 'key'...
# 1      {'danceability': 0.852, 'energy': 0.773, 'key'...
# 2      {'danceability': 0.852, 'energy': 0.773, 'key'...
# 3      {'danceability': 0.852, 'energy': 0.773, 'key'...
# 4      {'danceability': 0.852, 'energy': 0.773, 'key'...
#                              ...
# 339    {'danceability': 0.852, 'energy': 0.773, 'key'...
# 340    {'danceability': 0.852, 'energy': 0.773, 'key'...
# 341    {'danceability': 0.852, 'energy': 0.773, 'key'...
# 342    {'danceability': 0.852, 'energy': 0.773, 'key'...
# 343    {'danceability': 0.852, 'energy': 0.773, 'key'...
# Name: 0, Length: 344, dtype: object

# %%
data=[]
df3= pd.DataFrame(data,columns=["danceability","energy","key","loudness","mode","speechiness","acousticness","instrumentalness","liveness"
,"valence","tempo","type","id","uri","track_href","analysis_url","duration_ms","time_signature"])

# %%
for i in range(len(features)):
    df3= df3.append(df2[i],ignore_index=True)

# %%
spotify_data= pd.concat([df_song_artist, df3],axis=1).reset_index(drop=True)
spotify_data
# Out:
#                                                  songs        artists  \
# 0                              Chantaje (feat. Maluma)        Shakira
# 1                                             Mi Gente       J Balvin
# 2                                        Felices los 4         Maluma
# 3                           Reggaetón Lento (Bailemos)           CNCO
# 4                                           Ahora Dice     Chris Jedi
# ..                                                 ...            ...
# 339                                           Bichiyal      Bad Bunny
# 340  La Curiosidad (feat. Dj Nelson, Jhay Cortez, L...    Jay Wheeler
# 341                                         EL MAKINON        KAROL G
# 342                                           AM Remix     Nio Garcia
# 343                                        Cosas Malas  Manuel Turizo
#
#                                       uri  danceability  energy key  loudness  \
# 0    spotify:track:6mICuAdrwEjh6Y6lroV2Kg         0.852   0.773   8    -2.921
# 1    spotify:track:6mICuAdrwEjh6Y6lroV2Kg         0.852   0.773   8    -2.921
# 2    spotify:track:6mICuAdrwEjh6Y6lroV2Kg         0.852   0.773   8    -2.921
# 3    spotify:track:6mICuAdrwEjh6Y6lroV2Kg         0.852   0.773   8    -2.921
# 4    spotify:track:6mICuAdrwEjh6Y6lroV2Kg         0.852   0.773   8    -2.921
# ..                                    ...           ...     ...  ..       ...
# 339  spotify:track:6mICuAdrwEjh6Y6lroV2Kg         0.852   0.773   8    -2.921
# 340  spotify:track:6mICuAdrwEjh6Y6lroV2Kg         0.852   0.773   8    -2.921
# 341  spotify:track:6mICuAdrwEjh6Y6lroV2Kg         0.852   0.773   8    -2.921
# 342  spotify:track:6mICuAdrwEjh6Y6lroV2Kg         0.852   0.773   8    -2.921
# 343  spotify:track:6mICuAdrwEjh6Y6lroV2Kg         0.852   0.773   8    -2.921
#
#     mode  speechiness  acousticness  ...  liveness  valence    tempo  \
# 0      0       0.0776         0.187  ...     0.159    0.907  102.034
# 1      0       0.0776         0.187  ...     0.159    0.907  102.034
# 2      0       0.0776         0.187  ...     0.159    0.907  102.034
# 3      0       0.0776         0.187  ...     0.159    0.907  102.034
# 4      0       0.0776         0.187  ...     0.159    0.907  102.034
# ..   ...          ...           ...  ...       ...      ...      ...
# 339    0       0.0776         0.187  ...     0.159    0.907  102.034
# 340    0       0.0776         0.187  ...     0.159    0.907  102.034
# 341    0       0.0776         0.187  ...     0.159    0.907  102.034
# 342    0       0.0776         0.187  ...     0.159    0.907  102.034
# 343    0       0.0776         0.187  ...     0.159    0.907  102.034
#
#                type                      id  \
# 0    audio_features  6mICuAdrwEjh6Y6lroV2Kg
# 1    audio_features  6mICuAdrwEjh6Y6lroV2Kg
# 2    audio_features  6mICuAdrwEjh6Y6lroV2Kg
# 3    audio_features  6mICuAdrwEjh6Y6lroV2Kg
# 4    audio_features  6mICuAdrwEjh6Y6lroV2Kg
# ..              ...                     ...
# 339  audio_features  6mICuAdrwEjh6Y6lroV2Kg
# 340  audio_features  6mICuAdrwEjh6Y6lroV2Kg
# 341  audio_features  6mICuAdrwEjh6Y6lroV2Kg
# 342  audio_features  6mICuAdrwEjh6Y6lroV2Kg
# 343  audio_features  6mICuAdrwEjh6Y6lroV2Kg
#
#                                       uri  \
# 0    spotify:track:6mICuAdrwEjh6Y6lroV2Kg
# 1    spotify:track:6mICuAdrwEjh6Y6lroV2Kg
# 2    spotify:track:6mICuAdrwEjh6Y6lroV2Kg
# 3    spotify:track:6mICuAdrwEjh6Y6lroV2Kg
# 4    spotify:track:6mICuAdrwEjh6Y6lroV2Kg
# ..                                    ...
# 339  spotify:track:6mICuAdrwEjh6Y6lroV2Kg
# 340  spotify:track:6mICuAdrwEjh6Y6lroV2Kg
# 341  spotify:track:6mICuAdrwEjh6Y6lroV2Kg
# 342  spotify:track:6mICuAdrwEjh6Y6lroV2Kg
# 343  spotify:track:6mICuAdrwEjh6Y6lroV2Kg
#
#                                             track_href  \
# 0    https://api.spotify.com/v1/tracks/6mICuAdrwEjh...
# 1    https://api.spotify.com/v1/tracks/6mICuAdrwEjh...
# 2    https://api.spotify.com/v1/tracks/6mICuAdrwEjh...
# 3    https://api.spotify.com/v1/tracks/6mICuAdrwEjh...
# 4    https://api.spotify.com/v1/tracks/6mICuAdrwEjh...
# ..                                                 ...
# 339  https://api.spotify.com/v1/tracks/6mICuAdrwEjh...
# 340  https://api.spotify.com/v1/tracks/6mICuAdrwEjh...
# 341  https://api.spotify.com/v1/tracks/6mICuAdrwEjh...
# 342  https://api.spotify.com/v1/tracks/6mICuAdrwEjh...
# 343  https://api.spotify.com/v1/tracks/6mICuAdrwEjh...
#
#                                           analysis_url duration_ms  \
# 0    https://api.spotify.com/v1/audio-analysis/6mIC...      195840
# 1    https://api.spotify.com/v1/audio-analysis/6mIC...      195840
# 2    https://api.spotify.com/v1/audio-analysis/6mIC...      195840
# 3    https://api.spotify.com/v1/audio-analysis/6mIC...      195840
# 4    https://api.spotify.com/v1/audio-analysis/6mIC...      195840
# ..                                                 ...         ...
# 339  https://api.spotify.com/v1/audio-analysis/6mIC...      195840
# 340  https://api.spotify.com/v1/audio-analysis/6mIC...      195840
# 341  https://api.spotify.com/v1/audio-analysis/6mIC...      195840
# 342  https://api.spotify.com/v1/audio-analysis/6mIC...      195840
# 343  https://api.spotify.com/v1/audio-analysis/6mIC...      195840
#
#     time_signature
# 0                4
# 1                4
# 2                4
# 3                4
# 4                4
# ..             ...
# 339              4
# 340              4
# 341              4
# 342              4
# 343              4
#
# [344 rows x 21 columns]

# %%
spotify_data.to_csv("Data/Spanish_songs.csv",index=False)
