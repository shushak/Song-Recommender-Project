# %% [markdown]
# # Spotify DataBase

# %%
#We import the credential
import config
import pandas as pd
from time import sleep
from random import randint

# %%
#import the libraries we need 
import spotipy
import json
from spotipy.oauth2 import SpotifyClientCredentials

# %%
#Initialize SpotiPy with user credentias

sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=config.client_id,
                                                           client_secret=config.client_secret))

# %%
# We are going to extract the songs of the playlist:popular Spanish songs (https://open.spotify.com/playlist/7Lw0NIyg9L1mUcO1HL9C53)

playlist = sp.user_playlist_tracks("spotify", "7Lw0NIyg9L1mUcO1HL9C53",market="GB")

# %%
# we confirm the number of songs of our playlist. We have 10000 songs
print(list(playlist.keys())) # Let's look at items and total:
print("Total number of songs in the playlist: ",playlist["total"]) # 4Ksongs!! Let's check items:
len(playlist["items"])
# Out:
# ['href', 'items', 'limit', 'next', 'offset', 'previous', 'total']
# Total number of songs in the playlist:  967
# 100

# %%
def get_playlist_tracks(username, playlist_id):
    results = sp.user_playlist_tracks(username,playlist_id,market="GB")
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

# %%
track=get_playlist_tracks("spotify","7Lw0NIyg9L1mUcO1HL9C53")

# %%
track[0]
# Out:
# {'added_at': '2019-12-01T13:09:21Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/vr1edxk2vfl420oj1yzoietex'},
#   'href': 'https://api.spotify.com/v1/users/vr1edxk2vfl420oj1yzoietex',
#   'id': 'vr1edxk2vfl420oj1yzoietex',
#   'type': 'user',
#   'uri': 'spotify:user:vr1edxk2vfl420oj1yzoietex'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2p0UyoPfYfI76PCStuXfOP'},
#      'href': 'https://api.spotify.com/v1/artists/2p0UyoPfYfI76PCStuXfOP',
#      'id': '2p0UyoPfYfI76PCStuXfOP',
#      'name': 'Franz Schubert',
#      'type': 'artist',
#      'uri': 'spotify:artist:2p0UyoPfYfI76PCStuXfOP'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/003f4bk13c6Q3gAUXv7dGJ'},
#      'href': 'https://api.spotify.com/v1/artists/003f4bk13c6Q3gAUXv7dGJ',
#      'id': '003f4bk13c6Q3gAUXv7dGJ',
#      'name': 'Wiener Philharmoniker',
#      'type': 'artist',
#      'uri': 'spotify:artist:003f4bk13c6Q3gAUXv7dGJ'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/5yxyJsFanEAuwSM5kOuZKc'},
#      'href': 'https://api.spotify.com/v1/artists/5yxyJsFanEAuwSM5kOuZKc',
#      'id': '5yxyJsFanEAuwSM5kOuZKc',
#      'name': 'London Symphony Orchestra',
#      'type': 'artist',
#      'uri': 'spotify:artist:5yxyJsFanEAuwSM5kOuZKc'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/55ZzUX5aeX7bKQyRMsQMbG'},
#      'href': 'https://api.spotify.com/v1/artists/55ZzUX5aeX7bKQyRMsQMbG',
#      'id': '55ZzUX5aeX7bKQyRMsQMbG',
#      'name': 'Josef Krips',
#      'type': 'artist',
#      'uri': 'spotify:artist:55ZzUX5aeX7bKQyRMsQMbG'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/2nFVSsVHVJtGAnw37l8hwC'},
#    'href': 'https://api.spotify.com/v1/albums/2nFVSsVHVJtGAnw37l8hwC',
#    'id': '2nFVSsVHVJtGAnw37l8hwC',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2732ea761961cd0348909a0fcad',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e022ea761961cd0348909a0fcad',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048512ea761961cd0348909a0fcad',
#      'width': 64}],
#    'name': 'Schubert: Symphony No.8 "Unfinished"; Symphony No.9 "Great"',
#    'release_date': '1997-01-01',
#    'release_date_precision': 'day',
#    'total_tracks': 6,
#    'type': 'album',
#    'uri': 'spotify:album:2nFVSsVHVJtGAnw37l8hwC'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2p0UyoPfYfI76PCStuXfOP'},
#     'href': 'https://api.spotify.com/v1/artists/2p0UyoPfYfI76PCStuXfOP',
#     'id': '2p0UyoPfYfI76PCStuXfOP',
#     'name': 'Franz Schubert',
#     'type': 'artist',
#     'uri': 'spotify:artist:2p0UyoPfYfI76PCStuXfOP'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/003f4bk13c6Q3gAUXv7dGJ'},
#     'href': 'https://api.spotify.com/v1/artists/003f4bk13c6Q3gAUXv7dGJ',
#     'id': '003f4bk13c6Q3gAUXv7dGJ',
#     'name': 'Wiener Philharmoniker',
#     'type': 'artist',
#     'uri': 'spotify:artist:003f4bk13c6Q3gAUXv7dGJ'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/55ZzUX5aeX7bKQyRMsQMbG'},
#     'href': 'https://api.spotify.com/v1/artists/55ZzUX5aeX7bKQyRMsQMbG',
#     'id': '55ZzUX5aeX7bKQyRMsQMbG',
#     'name': 'Josef Krips',
#     'type': 'artist',
#     'uri': 'spotify:artist:55ZzUX5aeX7bKQyRMsQMbG'}],
#   'disc_number': 1,
#   'duration_ms': 906000,
#   'episode': False,
#   'explicit': False,
#   'external_ids': {'isrc': 'GBF076911031'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/52GmHO5DikTIKc3yBmTTT1'},
#   'href': 'https://api.spotify.com/v1/tracks/52GmHO5DikTIKc3yBmTTT1',
#   'id': '52GmHO5DikTIKc3yBmTTT1',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Symphony No.8 in B minor, D.759 - "Unfinished": 1. Allegro moderato',
#   'popularity': 45,
#   'preview_url': None,
#   'track': True,
#   'track_number': 5,
#   'type': 'track',
#   'uri': 'spotify:track:52GmHO5DikTIKc3yBmTTT1'},
#  'video_thumbnail': {'url': None}}

# %% [markdown]
# # Getting the songs and the artists of the playlist

# %%
# How we get the song
track[0]["track"]["name"]
# Out:
# 'Symphony No.8 in B minor, D.759 - "Unfinished": 1. Allegro moderato'

# %%
# how we get the artist
track[0]["track"]["artists"][0]["name"]
# Out:
# 'Franz Schubert'

# %%
track[0]["track"]["uri"]
# Out:
# 'spotify:track:52GmHO5DikTIKc3yBmTTT1'

# %%
# function to get the songs and artist
songs=[]
artists=[]
uri=[]

for i in range(len(track)):
    uri.append(track[0]["track"]["uri"])
    songs.append(track[i]["track"]["name"])
    artists.append(track[i]["track"]["artists"][0]["name"])

# %%
uri
# Out:
# ['spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'spotify:track:52GmHO5DikTIKc3yBmTTT1']

# %% [markdown]
# # Get the most important features

# %%
sp.audio_features(track[0]["track"]["uri"])
# Out:
# [{'danceability': 0.1,
#   'energy': 0.0354,
#   'key': 11,
#   'loudness': -17.211,
#   'mode': 0,
#   'speechiness': 0.0387,
#   'acousticness': 0.901,
#   'instrumentalness': 0.865,
#   'liveness': 0.125,
#   'valence': 0.0426,
#   'tempo': 73.968,
#   'type': 'audio_features',
#   'id': '52GmHO5DikTIKc3yBmTTT1',
#   'uri': 'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#   'track_href': 'https://api.spotify.com/v1/tracks/52GmHO5DikTIKc3yBmTTT1',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/52GmHO5DikTIKc3yBmTTT1',
#   'duration_ms': 906000,
#   'time_signature': 4}]

# %%
df_song_artist=pd.DataFrame({"songs":songs,"artists":artists,"uri":uri})

# %%
df_song_artist
# Out:
#                                                  songs  \
# 0    Symphony No.8 in B minor, D.759 - "Unfinished"...
# 1    Symphony No.8 in B minor, D.759 - "Unfinished"...
# 2                       In the Steppes of Central Asia
# 3                                    Finlandia, Op. 26
# 4    Pomp and Circumstance, Op. 39: March No. 1 in ...
# ..                                                 ...
# 962                        Die Forelle, Op. 32, D. 550
# 963  Il barbiere di Siviglia (The Barber of Seville...
# 964                        Gastaldon : Musica proibita
# 965                      Fantasina in C Major, Op. 124
# 966                 Intermezzo in A Minor Op. 76 No. 7
#
#                               artists                                   uri
# 0                      Franz Schubert  spotify:track:52GmHO5DikTIKc3yBmTTT1
# 1                      Franz Schubert  spotify:track:52GmHO5DikTIKc3yBmTTT1
# 2                   Alexander Borodin  spotify:track:52GmHO5DikTIKc3yBmTTT1
# 3                       Jean Sibelius  spotify:track:52GmHO5DikTIKc3yBmTTT1
# 4                        Edward Elgar  spotify:track:52GmHO5DikTIKc3yBmTTT1
# ..                                ...                                   ...
# 962                    Franz Schubert  spotify:track:52GmHO5DikTIKc3yBmTTT1
# 963                 Gioachino Rossini  spotify:track:52GmHO5DikTIKc3yBmTTT1
# 964  Stanislaus Gastaldon (1861-1939)  spotify:track:52GmHO5DikTIKc3yBmTTT1
# 965             Johann Nepomuk Hummel  spotify:track:52GmHO5DikTIKc3yBmTTT1
# 966                   Johannes Brahms  spotify:track:52GmHO5DikTIKc3yBmTTT1
#
# [967 rows x 3 columns]

# %%
song = sp.search(q="pepas", limit=1) 
#pprint.pprint(song['tracks']['items'][0]['uri'])
song["tracks"]["items"][0]["uri"]
sp.audio_features(song["tracks"]["items"][0]["uri"])[0]
# Out:
# {'danceability': 0.762,
#  'energy': 0.766,
#  'key': 7,
#  'loudness': -3.955,
#  'mode': 1,
#  'speechiness': 0.0343,
#  'acousticness': 0.00776,
#  'instrumentalness': 6.98e-05,
#  'liveness': 0.128,
#  'valence': 0.442,
#  'tempo': 130.001,
#  'type': 'audio_features',
#  'id': '5fwSHlTEWpluwOM0Sxnh5k',
#  'uri': 'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'track_href': 'https://api.spotify.com/v1/tracks/5fwSHlTEWpluwOM0Sxnh5k',
#  'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5fwSHlTEWpluwOM0Sxnh5k',
#  'duration_ms': 287120,
#  'time_signature': 4}

# %%
features=[]

for i in range(len(track)):
    if i%50==0:
        seconds_to_wait = randint(0,1)
        print("Wating {} seconds before scraping the next website!".format(seconds_to_wait))
        sleep(seconds_to_wait)
    
    feature= sp.audio_features(uri[i])
    features.append(feature)
# Out:
# Wating 0 seconds before scraping the next website!
# Wating 1 seconds before scraping the next website!
# Wating 0 seconds before scraping the next website!
# Wating 0 seconds before scraping the next website!
# Wating 0 seconds before scraping the next website!
# Wating 1 seconds before scraping the next website!
# Wating 1 seconds before scraping the next website!
# Wating 0 seconds before scraping the next website!
# Wating 0 seconds before scraping the next website!
# Wating 1 seconds before scraping the next website!
# Wating 1 seconds before scraping the next website!
# Wating 0 seconds before scraping the next website!
# Wating 1 seconds before scraping the next website!
# Wating 0 seconds before scraping the next website!
# Wating 1 seconds before scraping the next website!
# Wating 0 seconds before scraping the next website!
# Wating 0 seconds before scraping the next website!
# Wating 1 seconds before scraping the next website!
# Wating 0 seconds before scraping the next website!
# Wating 1 seconds before scraping the next website!

# %%
features[1][0]
# Out:
# {'danceability': 0.1,
#  'energy': 0.0354,
#  'key': 11,
#  'loudness': -17.211,
#  'mode': 0,
#  'speechiness': 0.0387,
#  'acousticness': 0.901,
#  'instrumentalness': 0.865,
#  'liveness': 0.125,
#  'valence': 0.0426,
#  'tempo': 73.968,
#  'type': 'audio_features',
#  'id': '52GmHO5DikTIKc3yBmTTT1',
#  'uri': 'spotify:track:52GmHO5DikTIKc3yBmTTT1',
#  'track_href': 'https://api.spotify.com/v1/tracks/52GmHO5DikTIKc3yBmTTT1',
#  'analysis_url': 'https://api.spotify.com/v1/audio-analysis/52GmHO5DikTIKc3yBmTTT1',
#  'duration_ms': 906000,
#  'time_signature': 4}

# %%
data=[]
df2=pd.DataFrame(features)
df2=df2[0]
df2
# Out:
# 0      {'danceability': 0.1, 'energy': 0.0354, 'key':...
# 1      {'danceability': 0.1, 'energy': 0.0354, 'key':...
# 2      {'danceability': 0.1, 'energy': 0.0354, 'key':...
# 3      {'danceability': 0.1, 'energy': 0.0354, 'key':...
# 4      {'danceability': 0.1, 'energy': 0.0354, 'key':...
#                              ...
# 962    {'danceability': 0.1, 'energy': 0.0354, 'key':...
# 963    {'danceability': 0.1, 'energy': 0.0354, 'key':...
# 964    {'danceability': 0.1, 'energy': 0.0354, 'key':...
# 965    {'danceability': 0.1, 'energy': 0.0354, 'key':...
# 966    {'danceability': 0.1, 'energy': 0.0354, 'key':...
# Name: 0, Length: 967, dtype: object

# %%
data=[]
df3= pd.DataFrame(data,columns=["danceability","energy","key","loudness","mode","speechiness","acousticness","instrumentalness","liveness"
,"valence","tempo","type","id","uri","track_href","analysis_url","duration_ms","time_signature"])

# %%
for i in range(len(features)):
    df3= df3.append(df2[i],ignore_index=True)

# %%
spotify_data= pd.concat([df_song_artist, df3],axis=1).reset_index(drop=True)
spotify_data
# Out:
#                                                  songs  \
# 0    Symphony No.8 in B minor, D.759 - "Unfinished"...
# 1    Symphony No.8 in B minor, D.759 - "Unfinished"...
# 2                       In the Steppes of Central Asia
# 3                                    Finlandia, Op. 26
# 4    Pomp and Circumstance, Op. 39: March No. 1 in ...
# ..                                                 ...
# 962                        Die Forelle, Op. 32, D. 550
# 963  Il barbiere di Siviglia (The Barber of Seville...
# 964                        Gastaldon : Musica proibita
# 965                      Fantasina in C Major, Op. 124
# 966                 Intermezzo in A Minor Op. 76 No. 7
#
#                               artists                                   uri  \
# 0                      Franz Schubert  spotify:track:52GmHO5DikTIKc3yBmTTT1
# 1                      Franz Schubert  spotify:track:52GmHO5DikTIKc3yBmTTT1
# 2                   Alexander Borodin  spotify:track:52GmHO5DikTIKc3yBmTTT1
# 3                       Jean Sibelius  spotify:track:52GmHO5DikTIKc3yBmTTT1
# 4                        Edward Elgar  spotify:track:52GmHO5DikTIKc3yBmTTT1
# ..                                ...                                   ...
# 962                    Franz Schubert  spotify:track:52GmHO5DikTIKc3yBmTTT1
# 963                 Gioachino Rossini  spotify:track:52GmHO5DikTIKc3yBmTTT1
# 964  Stanislaus Gastaldon (1861-1939)  spotify:track:52GmHO5DikTIKc3yBmTTT1
# 965             Johann Nepomuk Hummel  spotify:track:52GmHO5DikTIKc3yBmTTT1
# 966                   Johannes Brahms  spotify:track:52GmHO5DikTIKc3yBmTTT1
#
#      danceability  energy key  loudness mode  speechiness  acousticness  ...  \
# 0             0.1  0.0354  11   -17.211    0       0.0387         0.901  ...
# 1             0.1  0.0354  11   -17.211    0       0.0387         0.901  ...
# 2             0.1  0.0354  11   -17.211    0       0.0387         0.901  ...
# 3             0.1  0.0354  11   -17.211    0       0.0387         0.901  ...
# 4             0.1  0.0354  11   -17.211    0       0.0387         0.901  ...
# ..            ...     ...  ..       ...  ...          ...           ...  ...
# 962           0.1  0.0354  11   -17.211    0       0.0387         0.901  ...
# 963           0.1  0.0354  11   -17.211    0       0.0387         0.901  ...
# 964           0.1  0.0354  11   -17.211    0       0.0387         0.901  ...
# 965           0.1  0.0354  11   -17.211    0       0.0387         0.901  ...
# 966           0.1  0.0354  11   -17.211    0       0.0387         0.901  ...
#
#      liveness  valence   tempo            type                      id  \
# 0       0.125   0.0426  73.968  audio_features  52GmHO5DikTIKc3yBmTTT1
# 1       0.125   0.0426  73.968  audio_features  52GmHO5DikTIKc3yBmTTT1
# 2       0.125   0.0426  73.968  audio_features  52GmHO5DikTIKc3yBmTTT1
# 3       0.125   0.0426  73.968  audio_features  52GmHO5DikTIKc3yBmTTT1
# 4       0.125   0.0426  73.968  audio_features  52GmHO5DikTIKc3yBmTTT1
# ..        ...      ...     ...             ...                     ...
# 962     0.125   0.0426  73.968  audio_features  52GmHO5DikTIKc3yBmTTT1
# 963     0.125   0.0426  73.968  audio_features  52GmHO5DikTIKc3yBmTTT1
# 964     0.125   0.0426  73.968  audio_features  52GmHO5DikTIKc3yBmTTT1
# 965     0.125   0.0426  73.968  audio_features  52GmHO5DikTIKc3yBmTTT1
# 966     0.125   0.0426  73.968  audio_features  52GmHO5DikTIKc3yBmTTT1
#
#                                       uri  \
# 0    spotify:track:52GmHO5DikTIKc3yBmTTT1
# 1    spotify:track:52GmHO5DikTIKc3yBmTTT1
# 2    spotify:track:52GmHO5DikTIKc3yBmTTT1
# 3    spotify:track:52GmHO5DikTIKc3yBmTTT1
# 4    spotify:track:52GmHO5DikTIKc3yBmTTT1
# ..                                    ...
# 962  spotify:track:52GmHO5DikTIKc3yBmTTT1
# 963  spotify:track:52GmHO5DikTIKc3yBmTTT1
# 964  spotify:track:52GmHO5DikTIKc3yBmTTT1
# 965  spotify:track:52GmHO5DikTIKc3yBmTTT1
# 966  spotify:track:52GmHO5DikTIKc3yBmTTT1
#
#                                             track_href  \
# 0    https://api.spotify.com/v1/tracks/52GmHO5DikTI...
# 1    https://api.spotify.com/v1/tracks/52GmHO5DikTI...
# 2    https://api.spotify.com/v1/tracks/52GmHO5DikTI...
# 3    https://api.spotify.com/v1/tracks/52GmHO5DikTI...
# 4    https://api.spotify.com/v1/tracks/52GmHO5DikTI...
# ..                                                 ...
# 962  https://api.spotify.com/v1/tracks/52GmHO5DikTI...
# 963  https://api.spotify.com/v1/tracks/52GmHO5DikTI...
# 964  https://api.spotify.com/v1/tracks/52GmHO5DikTI...
# 965  https://api.spotify.com/v1/tracks/52GmHO5DikTI...
# 966  https://api.spotify.com/v1/tracks/52GmHO5DikTI...
#
#                                           analysis_url duration_ms  \
# 0    https://api.spotify.com/v1/audio-analysis/52Gm...      906000
# 1    https://api.spotify.com/v1/audio-analysis/52Gm...      906000
# 2    https://api.spotify.com/v1/audio-analysis/52Gm...      906000
# 3    https://api.spotify.com/v1/audio-analysis/52Gm...      906000
# 4    https://api.spotify.com/v1/audio-analysis/52Gm...      906000
# ..                                                 ...         ...
# 962  https://api.spotify.com/v1/audio-analysis/52Gm...      906000
# 963  https://api.spotify.com/v1/audio-analysis/52Gm...      906000
# 964  https://api.spotify.com/v1/audio-analysis/52Gm...      906000
# 965  https://api.spotify.com/v1/audio-analysis/52Gm...      906000
# 966  https://api.spotify.com/v1/audio-analysis/52Gm...      906000
#
#     time_signature
# 0                4
# 1                4
# 2                4
# 3                4
# 4                4
# ..             ...
# 962              4
# 963              4
# 964              4
# 965              4
# 966              4
#
# [967 rows x 21 columns]

# %%
spotify_data.to_csv("Data/Clasic_music.csv",index=False)
