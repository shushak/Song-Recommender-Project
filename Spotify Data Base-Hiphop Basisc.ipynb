# %% [markdown]
# # Spotify DataBase

# %%
#We import the credential
import config
import pandas as pd
from time import sleep
from random import randint

# %%
#import the libraries we need 
import spotipy
import json
from spotipy.oauth2 import SpotifyClientCredentials

# %%
#Initialize SpotiPy with user credentias

sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=config.client_id,
                                                           client_secret=config.client_secret))

# %%
# We are going to extract the songs of the playlist:Hip hop basisc (https://open.spotify.com/playlist/5CRJExGSQFYXem2hT5GFkd)

playlist = sp.user_playlist_tracks("spotify", "5CRJExGSQFYXem2hT5GFkd",market="GB")

# %%
# we confirm the number of songs of our playlist. We have 10000 songs
print(list(playlist.keys())) # Let's look at items and total:
print("Total number of songs in the playlist: ",playlist["total"]) # 4Ksongs!! Let's check items:
len(playlist["items"])
# Out:
# ['href', 'items', 'limit', 'next', 'offset', 'previous', 'total']
# Total number of songs in the playlist:  230
# 100

# %%
def get_playlist_tracks(username, playlist_id):
    results = sp.user_playlist_tracks(username,playlist_id,market="GB")
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

# %%
track=get_playlist_tracks("spotify","5CRJExGSQFYXem2hT5GFkd")

# %%
track[0]
# Out:
# {'added_at': '2016-02-12T11:19:10Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1167987881'},
#   'href': 'https://api.spotify.com/v1/users/1167987881',
#   'id': '1167987881',
#   'type': 'user',
#   'uri': 'spotify:user:1167987881'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1ZwdS5xdxEREPySFridCfh'},
#      'href': 'https://api.spotify.com/v1/artists/1ZwdS5xdxEREPySFridCfh',
#      'id': '1ZwdS5xdxEREPySFridCfh',
#      'name': '2Pac',
#      'type': 'artist',
#      'uri': 'spotify:artist:1ZwdS5xdxEREPySFridCfh'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/3OrucS4sHv6Bl9GS4rafEk'},
#    'href': 'https://api.spotify.com/v1/albums/3OrucS4sHv6Bl9GS4rafEk',
#    'id': '3OrucS4sHv6Bl9GS4rafEk',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b27304b9ab6bd4bf6a350ba902ea',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e0204b9ab6bd4bf6a350ba902ea',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d0000485104b9ab6bd4bf6a350ba902ea',
#      'width': 64}],
#    'name': 'Me Against The World',
#    'release_date': '1995-03-14',
#    'release_date_precision': 'day',
#    'total_tracks': 15,
#    'type': 'album',
#    'uri': 'spotify:album:3OrucS4sHv6Bl9GS4rafEk'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1ZwdS5xdxEREPySFridCfh'},
#     'href': 'https://api.spotify.com/v1/artists/1ZwdS5xdxEREPySFridCfh',
#     'id': '1ZwdS5xdxEREPySFridCfh',
#     'name': '2Pac',
#     'type': 'artist',
#     'uri': 'spotify:artist:1ZwdS5xdxEREPySFridCfh'}],
#   'disc_number': 1,
#   'duration_ms': 280000,
#   'episode': False,
#   'explicit': True,
#   'external_ids': {'isrc': 'USIR19500009'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/6tDxrq4FxEL2q15y37tXT9'},
#   'href': 'https://api.spotify.com/v1/tracks/6tDxrq4FxEL2q15y37tXT9',
#   'id': '6tDxrq4FxEL2q15y37tXT9',
#   'is_local': False,
#   'is_playable': True,
#   'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/0z5Uqcync4DGshMmfvz0VK'},
#    'href': 'https://api.spotify.com/v1/tracks/0z5Uqcync4DGshMmfvz0VK',
#    'id': '0z5Uqcync4DGshMmfvz0VK',
#    'type': 'track',
#    'uri': 'spotify:track:0z5Uqcync4DGshMmfvz0VK'},
#   'name': 'Dear Mama',
#   'popularity': 72,
#   'preview_url': None,
#   'track': True,
#   'track_number': 9,
#   'type': 'track',
#   'uri': 'spotify:track:6tDxrq4FxEL2q15y37tXT9'},
#  'video_thumbnail': {'url': None}}

# %% [markdown]
# # Getting the songs and the artists of the playlist

# %%
# How we get the song
track[0]["track"]["name"]
# Out:
# 'Dear Mama'

# %%
# how we get the artist
track[0]["track"]["artists"][0]["name"]
# Out:
# '2Pac'

# %%
track[0]["track"]["uri"]
# Out:
# 'spotify:track:6tDxrq4FxEL2q15y37tXT9'

# %%
# function to get the songs and artist
songs=[]
artists=[]
uri=[]

for i in range(len(track)):
    uri.append(track[0]["track"]["uri"])
    songs.append(track[i]["track"]["name"])
    artists.append(track[i]["track"]["artists"][0]["name"])

# %%
uri
# Out:
# ['spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'spotify:track:6tDxrq4FxEL2q15y37tXT9']

# %% [markdown]
# # Get the most important features

# %%
sp.audio_features(track[0]["track"]["uri"])
# Out:
# [{'danceability': 0.773,
#   'energy': 0.54,
#   'key': 6,
#   'loudness': -7.123,
#   'mode': 1,
#   'speechiness': 0.103,
#   'acousticness': 0.371,
#   'instrumentalness': 0,
#   'liveness': 0.131,
#   'valence': 0.322,
#   'tempo': 84.115,
#   'type': 'audio_features',
#   'id': '6tDxrq4FxEL2q15y37tXT9',
#   'uri': 'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#   'track_href': 'https://api.spotify.com/v1/tracks/6tDxrq4FxEL2q15y37tXT9',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6tDxrq4FxEL2q15y37tXT9',
#   'duration_ms': 280000,
#   'time_signature': 4}]

# %%
df_song_artist=pd.DataFrame({"songs":songs,"artists":artists,"uri":uri})

# %%
df_song_artist
# Out:
#                                                 songs               artists  \
# 0                                           Dear Mama                  2Pac
# 1                           Big Poppa - 2007 Remaster  The Notorious B.I.G.
# 2                                    Jazz (We've Got)  A Tribe Called Quest
# 3         Sky's the Limit (feat. 112) - 2014 Remaster  The Notorious B.I.G.
# 4                                           Xxplosive               Dr. Dre
# ..                                                ...                   ...
# 225                                   Flava in Ya Ear            Craig Mack
# 226                                  How High (Remix)            Method Man
# 227  Buy U a Drank (Shawty Snappin') (feat. Yung Joc)                T-Pain
# 228                   Southernplayalisticadillacmuzik               Outkast
# 229                             Wanna Get To Know You                G-Unit
#
#                                       uri
# 0    spotify:track:6tDxrq4FxEL2q15y37tXT9
# 1    spotify:track:6tDxrq4FxEL2q15y37tXT9
# 2    spotify:track:6tDxrq4FxEL2q15y37tXT9
# 3    spotify:track:6tDxrq4FxEL2q15y37tXT9
# 4    spotify:track:6tDxrq4FxEL2q15y37tXT9
# ..                                    ...
# 225  spotify:track:6tDxrq4FxEL2q15y37tXT9
# 226  spotify:track:6tDxrq4FxEL2q15y37tXT9
# 227  spotify:track:6tDxrq4FxEL2q15y37tXT9
# 228  spotify:track:6tDxrq4FxEL2q15y37tXT9
# 229  spotify:track:6tDxrq4FxEL2q15y37tXT9
#
# [230 rows x 3 columns]

# %%
song = sp.search(q="pepas", limit=1) 
#pprint.pprint(song['tracks']['items'][0]['uri'])
song["tracks"]["items"][0]["uri"]
sp.audio_features(song["tracks"]["items"][0]["uri"])[0]
# Out:
# {'danceability': 0.762,
#  'energy': 0.766,
#  'key': 7,
#  'loudness': -3.955,
#  'mode': 1,
#  'speechiness': 0.0343,
#  'acousticness': 0.00776,
#  'instrumentalness': 6.98e-05,
#  'liveness': 0.128,
#  'valence': 0.442,
#  'tempo': 130.001,
#  'type': 'audio_features',
#  'id': '5fwSHlTEWpluwOM0Sxnh5k',
#  'uri': 'spotify:track:5fwSHlTEWpluwOM0Sxnh5k',
#  'track_href': 'https://api.spotify.com/v1/tracks/5fwSHlTEWpluwOM0Sxnh5k',
#  'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5fwSHlTEWpluwOM0Sxnh5k',
#  'duration_ms': 287120,
#  'time_signature': 4}

# %%
features=[]

for i in range(len(track)):
    if i%50==0:
        seconds_to_wait = randint(0,1)
        print("Wating {} seconds before scraping the next website!".format(seconds_to_wait))
        sleep(seconds_to_wait)
    
    feature= sp.audio_features(uri[i])
    features.append(feature)
# Out:
# Wating 1 seconds before scraping the next website!
# Wating 0 seconds before scraping the next website!
# Wating 0 seconds before scraping the next website!
# Wating 1 seconds before scraping the next website!
# Wating 0 seconds before scraping the next website!

# %%
features[1][0]
# Out:
# {'danceability': 0.773,
#  'energy': 0.54,
#  'key': 6,
#  'loudness': -7.123,
#  'mode': 1,
#  'speechiness': 0.103,
#  'acousticness': 0.371,
#  'instrumentalness': 0,
#  'liveness': 0.131,
#  'valence': 0.322,
#  'tempo': 84.115,
#  'type': 'audio_features',
#  'id': '6tDxrq4FxEL2q15y37tXT9',
#  'uri': 'spotify:track:6tDxrq4FxEL2q15y37tXT9',
#  'track_href': 'https://api.spotify.com/v1/tracks/6tDxrq4FxEL2q15y37tXT9',
#  'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6tDxrq4FxEL2q15y37tXT9',
#  'duration_ms': 280000,
#  'time_signature': 4}

# %%
data=[]
df2=pd.DataFrame(features)
df2=df2[0]
df2
# Out:
# 0      {'danceability': 0.773, 'energy': 0.54, 'key':...
# 1      {'danceability': 0.773, 'energy': 0.54, 'key':...
# 2      {'danceability': 0.773, 'energy': 0.54, 'key':...
# 3      {'danceability': 0.773, 'energy': 0.54, 'key':...
# 4      {'danceability': 0.773, 'energy': 0.54, 'key':...
#                              ...
# 225    {'danceability': 0.773, 'energy': 0.54, 'key':...
# 226    {'danceability': 0.773, 'energy': 0.54, 'key':...
# 227    {'danceability': 0.773, 'energy': 0.54, 'key':...
# 228    {'danceability': 0.773, 'energy': 0.54, 'key':...
# 229    {'danceability': 0.773, 'energy': 0.54, 'key':...
# Name: 0, Length: 230, dtype: object

# %%
data=[]
df3= pd.DataFrame(data,columns=["danceability","energy","key","loudness","mode","speechiness","acousticness","instrumentalness","liveness"
,"valence","tempo","type","id","uri","track_href","analysis_url","duration_ms","time_signature"])

# %%
for i in range(len(features)):
    df3= df3.append(df2[i],ignore_index=True)

# %%
spotify_data= pd.concat([df_song_artist, df3],axis=1).reset_index(drop=True)
spotify_data
# Out:
#                                                 songs               artists  \
# 0                                           Dear Mama                  2Pac
# 1                           Big Poppa - 2007 Remaster  The Notorious B.I.G.
# 2                                    Jazz (We've Got)  A Tribe Called Quest
# 3         Sky's the Limit (feat. 112) - 2014 Remaster  The Notorious B.I.G.
# 4                                           Xxplosive               Dr. Dre
# ..                                                ...                   ...
# 225                                   Flava in Ya Ear            Craig Mack
# 226                                  How High (Remix)            Method Man
# 227  Buy U a Drank (Shawty Snappin') (feat. Yung Joc)                T-Pain
# 228                   Southernplayalisticadillacmuzik               Outkast
# 229                             Wanna Get To Know You                G-Unit
#
#                                       uri  danceability  energy key  loudness  \
# 0    spotify:track:6tDxrq4FxEL2q15y37tXT9         0.773    0.54   6    -7.123
# 1    spotify:track:6tDxrq4FxEL2q15y37tXT9         0.773    0.54   6    -7.123
# 2    spotify:track:6tDxrq4FxEL2q15y37tXT9         0.773    0.54   6    -7.123
# 3    spotify:track:6tDxrq4FxEL2q15y37tXT9         0.773    0.54   6    -7.123
# 4    spotify:track:6tDxrq4FxEL2q15y37tXT9         0.773    0.54   6    -7.123
# ..                                    ...           ...     ...  ..       ...
# 225  spotify:track:6tDxrq4FxEL2q15y37tXT9         0.773    0.54   6    -7.123
# 226  spotify:track:6tDxrq4FxEL2q15y37tXT9         0.773    0.54   6    -7.123
# 227  spotify:track:6tDxrq4FxEL2q15y37tXT9         0.773    0.54   6    -7.123
# 228  spotify:track:6tDxrq4FxEL2q15y37tXT9         0.773    0.54   6    -7.123
# 229  spotify:track:6tDxrq4FxEL2q15y37tXT9         0.773    0.54   6    -7.123
#
#     mode  speechiness  acousticness  ... liveness  valence   tempo  \
# 0      1        0.103         0.371  ...    0.131    0.322  84.115
# 1      1        0.103         0.371  ...    0.131    0.322  84.115
# 2      1        0.103         0.371  ...    0.131    0.322  84.115
# 3      1        0.103         0.371  ...    0.131    0.322  84.115
# 4      1        0.103         0.371  ...    0.131    0.322  84.115
# ..   ...          ...           ...  ...      ...      ...     ...
# 225    1        0.103         0.371  ...    0.131    0.322  84.115
# 226    1        0.103         0.371  ...    0.131    0.322  84.115
# 227    1        0.103         0.371  ...    0.131    0.322  84.115
# 228    1        0.103         0.371  ...    0.131    0.322  84.115
# 229    1        0.103         0.371  ...    0.131    0.322  84.115
#
#                type                      id  \
# 0    audio_features  6tDxrq4FxEL2q15y37tXT9
# 1    audio_features  6tDxrq4FxEL2q15y37tXT9
# 2    audio_features  6tDxrq4FxEL2q15y37tXT9
# 3    audio_features  6tDxrq4FxEL2q15y37tXT9
# 4    audio_features  6tDxrq4FxEL2q15y37tXT9
# ..              ...                     ...
# 225  audio_features  6tDxrq4FxEL2q15y37tXT9
# 226  audio_features  6tDxrq4FxEL2q15y37tXT9
# 227  audio_features  6tDxrq4FxEL2q15y37tXT9
# 228  audio_features  6tDxrq4FxEL2q15y37tXT9
# 229  audio_features  6tDxrq4FxEL2q15y37tXT9
#
#                                       uri  \
# 0    spotify:track:6tDxrq4FxEL2q15y37tXT9
# 1    spotify:track:6tDxrq4FxEL2q15y37tXT9
# 2    spotify:track:6tDxrq4FxEL2q15y37tXT9
# 3    spotify:track:6tDxrq4FxEL2q15y37tXT9
# 4    spotify:track:6tDxrq4FxEL2q15y37tXT9
# ..                                    ...
# 225  spotify:track:6tDxrq4FxEL2q15y37tXT9
# 226  spotify:track:6tDxrq4FxEL2q15y37tXT9
# 227  spotify:track:6tDxrq4FxEL2q15y37tXT9
# 228  spotify:track:6tDxrq4FxEL2q15y37tXT9
# 229  spotify:track:6tDxrq4FxEL2q15y37tXT9
#
#                                             track_href  \
# 0    https://api.spotify.com/v1/tracks/6tDxrq4FxEL2...
# 1    https://api.spotify.com/v1/tracks/6tDxrq4FxEL2...
# 2    https://api.spotify.com/v1/tracks/6tDxrq4FxEL2...
# 3    https://api.spotify.com/v1/tracks/6tDxrq4FxEL2...
# 4    https://api.spotify.com/v1/tracks/6tDxrq4FxEL2...
# ..                                                 ...
# 225  https://api.spotify.com/v1/tracks/6tDxrq4FxEL2...
# 226  https://api.spotify.com/v1/tracks/6tDxrq4FxEL2...
# 227  https://api.spotify.com/v1/tracks/6tDxrq4FxEL2...
# 228  https://api.spotify.com/v1/tracks/6tDxrq4FxEL2...
# 229  https://api.spotify.com/v1/tracks/6tDxrq4FxEL2...
#
#                                           analysis_url duration_ms  \
# 0    https://api.spotify.com/v1/audio-analysis/6tDx...      280000
# 1    https://api.spotify.com/v1/audio-analysis/6tDx...      280000
# 2    https://api.spotify.com/v1/audio-analysis/6tDx...      280000
# 3    https://api.spotify.com/v1/audio-analysis/6tDx...      280000
# 4    https://api.spotify.com/v1/audio-analysis/6tDx...      280000
# ..                                                 ...         ...
# 225  https://api.spotify.com/v1/audio-analysis/6tDx...      280000
# 226  https://api.spotify.com/v1/audio-analysis/6tDx...      280000
# 227  https://api.spotify.com/v1/audio-analysis/6tDx...      280000
# 228  https://api.spotify.com/v1/audio-analysis/6tDx...      280000
# 229  https://api.spotify.com/v1/audio-analysis/6tDx...      280000
#
#     time_signature
# 0                4
# 1                4
# 2                4
# 3                4
# 4                4
# ..             ...
# 225              4
# 226              4
# 227              4
# 228              4
# 229              4
#
# [230 rows x 21 columns]

# %%
spotify_data.to_csv("Data/hiphop.csv",index=False)
